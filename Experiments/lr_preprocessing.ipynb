# %%
import pandas as pd
import numpy as np
import re
import nltk
import joblib
from textblob import TextBlob
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Reading CSV and processing text**

# %%
def pre_process_text(df):
    text = list(df['text'])
    sentiment = []
    for i in range(len(text)):
        if type(text[i]) != float:
            text[i] = " ".join(filter(lambda x:x[0]!='@', text[i].split()))
            text[i] = " ".join(filter(lambda x:x[0:4]!='http', text[i].split()))
            text[i] = " ".join(filter(lambda x:x[0:4]!='&amp', text[i].split()))
            text[i] = re.sub(r'[^a-zA-Z ]','',text[i])
            text[i] = " ".join(filter(lambda x:x[0:1]!='Q', text[i].split()))
            text[i] = " ".join(filter(lambda x:x[0:1]!='A', text[i].split()))
        sentiment.append(TextBlob(str(text[i])).sentiment.polarity)
    return text, sentiment

# %%
def prepare_df(path):
    sources = joblib.load("Data/" + path)
    sources['text'], sources['polarity'] = pre_process_text(sources)
    sources.text = sources.text + " " + sources.hashtag
    return sources

# %%
train_sources = prepare_df('train_sources.data')
train_replies = prepare_df('train_replies.data')
dev_sources = prepare_df('dev_sources.data')
dev_replies = prepare_df('dev_replies.data')
test_sources = prepare_df('test_sources.data')
test_replies = prepare_df('test_replies.data')
train_sources
# Out:
#                          user verified   followers  \
# id
# 1218255692831903744       WHO     True  11173284.0
# 1218269428166602753       WHO     True  11173285.0
# 1219979825848442880       WHO     True  11173284.0
# 1219981282928668672       WHO     True  11173285.0
# 1219982106757148673       WHO     True  11173285.0
# ...                       ...      ...         ...
# 676367888543031296     nycjim     True    211869.0
# 676718762830221312    Complex     True   2574209.0
# 676870737932742656        ABC     True  17466165.0
# 677099574855639044        ABC     True  17466165.0
# 681767380305985536   mashable     True   9427476.0
#
#                                                                   text  \
# id
# 1218255692831903744  Is there a treatment for a novel coronavirus i...
# 1218269428166602753  What can I do to protect myself from coronavir...
# 1219979825848442880  Who are the members of an International Health...
# 1219981282928668672  How are the members of an International Health...
# 1219982106757148673  How are people appointed to the expert advisor...
# ...                                                                ...
# 676367888543031296   North Carolina town rejects solar panels for s...
# 676718762830221312   Texas plumber sues car dealership after his tr...
# 676870737932742656   Plumber suing car dealership for M after truck...
# 677099574855639044   Plumber suing car dealership for M after truck...
# 681767380305985536   Sorry Mark Zuckerberg is not giving billion to...
#
#                      retweets  favorites  statuses_count      hashtag  \
# id
# 1218255692831903744     202.0      265.0         69221.0  coronavirus
# 1218269428166602753    2007.0     2057.0         69221.0  coronavirus
# 1219979825848442880      20.0       43.0         69221.0  coronavirus
# 1219981282928668672      21.0       49.0         69221.0  coronavirus
# 1219982106757148673      19.0       44.0         69221.0  coronavirus
# ...                       ...        ...             ...          ...
# 676367888543031296      329.0      170.0        137128.0
# 676718762830221312      170.0      258.0        375499.0
# 676870737932742656      157.0       99.0        384381.0
# 677099574855639044      104.0       80.0        384381.0
# 681767380305985536       96.0       94.0        466664.0
#
#                          class  polarity
# id
# 1218255692831903744  nonrumour      0.25
# 1218269428166602753  nonrumour      0.00
# 1219979825848442880  nonrumour      0.00
# 1219981282928668672  nonrumour      0.00
# 1219982106757148673  nonrumour      0.00
# ...                        ...       ...
# 676367888543031296   nonrumour      0.00
# 676718762830221312      rumour      0.00
# 676870737932742656      rumour      0.00
# 677099574855639044      rumour      0.00
# 681767380305985536      rumour     -0.50
#
# [1561 rows x 10 columns]

# %% [markdown]
# Checking data is in correct format/dtypes

# %%
for df in [train_sources, train_replies, dev_sources, dev_replies, test_sources, test_replies]:
    print(df.dtypes)
# Out:
# user               object
# verified           object
# followers         float64
# text               object
# retweets          float64
# favorites         float64
# statuses_count    float64
# hashtag            object
# class              object
# polarity          float64
# dtype: object
# user               object
# verified             bool
# followers           int64
# text               object
# retweets            int64
# favorites           int64
# statuses_count      int64
# hashtag            object
# source id          object
# source class       object
# polarity          float64
# dtype: object
# user               object
# verified           object
# followers         float64
# text               object
# retweets          float64
# favorites         float64
# statuses_count    float64
# hashtag            object
# class              object
# polarity          float64
# dtype: object
# user               object
# verified             bool
# followers           int64
# text               object
# retweets            int64
# favorites           int64
# statuses_count      int64
# hashtag            object
# source id          object
# source class       object
# polarity          float64
# dtype: object
# user               object
# verified             bool
# followers           int64
# text               object
# retweets            int64
# favorites           int64
# statuses_count      int64
# hashtag            object
# polarity          float64
# dtype: object
# user               object
# verified             bool
# followers           int64
# text               object
# retweets            int64
# favorites           int64
# statuses_count      int64
# hashtag            object
# source id          object
# polarity          float64
# dtype: object

# %%
train_replies['source class'].value_counts()
# Out:
# nonrumour    15785
# rumour       12700
# Name: source class, dtype: int64

# %% [markdown]
# **Tokenize and lemmatize text**

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords, wordnet

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma

def create_tokens(df):
    tokens_list = []
    for _id, row in df.iterrows():
        text = row['text']
        # tokenize tweet
        tokens = tt.tokenize(text)
        # convert to lowercase
        tokens = [tok.lower() for tok in tokens]
        # remove stopwords
        tokens = [tok for tok in tokens if tok not in stopwords]
        # lemmatize
        tokens = [lemmatize(tok) for tok in tokens]
        
        tokens_list.append(tokens)

    return tokens_list

# %%
train_sources.insert(4, 'tokens', create_tokens(train_sources))
dev_sources.insert(4, 'tokens', create_tokens(dev_sources))
test_sources.insert(4, 'tokens', create_tokens(test_sources))
train_sources.head()
# Out:
#                     user verified   followers  \
# id
# 1218255692831903744  WHO     True  11173284.0
# 1218269428166602753  WHO     True  11173285.0
# 1219979825848442880  WHO     True  11173284.0
# 1219981282928668672  WHO     True  11173285.0
# 1219982106757148673  WHO     True  11173285.0
#
#                                                                   text  \
# id
# 1218255692831903744  Is there a treatment for a novel coronavirus i...
# 1218269428166602753  What can I do to protect myself from coronavir...
# 1219979825848442880  Who are the members of an International Health...
# 1219981282928668672  How are the members of an International Health...
# 1219982106757148673  How are people appointed to the expert advisor...
#
#                                                                 tokens  \
# id
# 1218255692831903744  [treatment, novel, coronavirus, infection, spe...
# 1218269428166602753                [protect, coronavirus, coronavirus]
# 1219979825848442880  [member, international, health, regulation, em...
# 1219981282928668672  [member, international, health, regulation, em...
# 1219982106757148673  [people, appoint, expert, advisory, panel, int...
#
#                      retweets  favorites  statuses_count      hashtag  \
# id
# 1218255692831903744     202.0      265.0         69221.0  coronavirus
# 1218269428166602753    2007.0     2057.0         69221.0  coronavirus
# 1219979825848442880      20.0       43.0         69221.0  coronavirus
# 1219981282928668672      21.0       49.0         69221.0  coronavirus
# 1219982106757148673      19.0       44.0         69221.0  coronavirus
#
#                          class  polarity
# id
# 1218255692831903744  nonrumour      0.25
# 1218269428166602753  nonrumour      0.00
# 1219979825848442880  nonrumour      0.00
# 1219981282928668672  nonrumour      0.00
# 1219982106757148673  nonrumour      0.00

# %%
train_replies.insert(4, 'tokens', create_tokens(train_replies))
dev_replies.insert(4, 'tokens', create_tokens(dev_replies))
test_replies.insert(4, 'tokens', create_tokens(test_replies))
train_replies.head()
# Out:
#                           user  verified  followers  \
# id
# 1250219116993974272  ucoptempe     False        410
# 1250219437027766273  ucoptempe     False        410
# 1250219620939657216  ucoptempe     False        410
# 1250219777185873922  ucoptempe     False        410
# 1250219894429208577  ucoptempe     False        410
#
#                                                                   text  \
# id
# 1250219116993974272  Can eating garlic help prevent infection with ...
# 1250219437027766273  Do vaccines against pneumonia protect you agai...
# 1250219620939657216  Can spraying alcohol or chlorine all over your...
# 1250219777185873922  How effective are thermal scanners in detectin...
# 1250219894429208577  Can an ultraviolet disinfection lamp kill the ...
#
#                                                                 tokens  \
# id
# 1250219116993974272  [eat, garlic, help, prevent, infection, new, c...
# 1250219437027766273    [vaccine, pneumonia, protect, new, coronavirus]
# 1250219620939657216  [spray, alcohol, chlorine, body, kill, new, co...
# 1250219777185873922  [effective, thermal, scanner, detect, people, ...
# 1250219894429208577  [ultraviolet, disinfection, lamp, kill, new, c...
#
#                      retweets  favorites  statuses_count          hashtag  \
# id
# 1250219116993974272         0          0           26613  COVID19Malaysia
# 1250219437027766273         0          0           26613
# 1250219620939657216         0          0           26613          Chamber
# 1250219777185873922         0          0           26613
# 1250219894429208577         0          0           26613
#
#                                source id source class  polarity
# id
# 1250219116993974272  1250219300389974016    nonrumour  0.136364
# 1250219437027766273  1250219300389974016    nonrumour  0.136364
# 1250219620939657216  1250219300389974016    nonrumour  0.136364
# 1250219777185873922  1250219300389974016    nonrumour  0.368182
# 1250219894429208577  1250219300389974016    nonrumour  0.136364

# %% [markdown]
# **Counting users**

# %%
# Finds users with multiple tweets in training data.
source_user_counts = train_sources.user.value_counts()
replies_user_counts = train_replies.user.value_counts()
source_user_counts
# Out:
# WHO              22
# ABC              16
# Independent      15
# WHOWPRO          13
# mashable         11
#                  ..
# ClarkeMicah       1
# kamalkano         1
# 62jerseygirl      1
# aparanjape        1
# topislamicnet     1
# Name: user, Length: 1099, dtype: int64

# %% [markdown]
# **Finding users with multiple tweets and removing users with only one tweet**

# %%
def find_multi_tweet_users(counts):
    multiple_tweet_users = []
    for id, count in counts.iteritems():
        if count > 1:
            multiple_tweet_users.append(id)
    return multiple_tweet_users

source_multiple_tweet_users = find_multi_tweet_users(source_user_counts)
replies_multiple_tweet_users = find_multi_tweet_users(replies_user_counts)
source_multiple_tweet_users
# Out:
# ['WHO',
#  'ABC',
#  'Independent',
#  'WHOWPRO',
#  'mashable',
#  'FoxNews',
#  'ucoptempe',
#  'RT_com',
#  'BuzzFeed',
#  'WSJ',
#  'AP',
#  'TIME',
#  'pepesikanteri',
#  'teawithdev',
#  'CNN',
#  'HuffPost',
#  'IshiwiMyVoice',
#  'OzgurTufekci',
#  'eteobong_edem',
#  'cnnbrk',
#  'Fact',
#  'CianSOBrien',
#  'lutzmache',
#  'Ausbones',
#  'NBCNews',
#  'eric_tablizo',
#  'enews',
#  'Wissenzoro',
#  'UNICEFJamaica',
#  'cnni',
#  'TMZ',
#  'gustasticgus',
#  'deray',
#  'YoungIndiaFDN',
#  'BamboVaneHope',
#  'nytimes',
#  'Complex',
#  'BreakingNews',
#  'ndmaindia',
#  'WHOSEARO',
#  'CBCNews',
#  'sagadkopaba',
#  'RepUrJersey',
#  'Agalib48',
#  'ThePoke',
#  'WHOUganda',
#  'Agali_GCFR',
#  'CBCAlerts',
#  'AVONHMO',
#  'UmerBasharat7',
#  'BBCBreaking',
#  'RoySparringa',
#  'WHONigeria',
#  'YourAnonNews',
#  'KKMPutrajaya',
#  'usweekly',
#  'CP24',
#  'Cosmopolitan',
#  'fursid',
#  'washingtonpost',
#  'AlbuniDouaa',
#  'TwitchyTeam',
#  'Telegraph',
#  'CNNPolitics',
#  'ALOKdelhi6',
#  'EyeRadioJuba',
#  'CBCTheNational',
#  'SavioSt',
#  'glowyrosecare',
#  'guardian',
#  'ChinaDaily',
#  'CBSNews',
#  'DailyMirror',
#  'GP_CommSafety',
#  'social_rural',
#  'WHOEMRO',
#  'brianwairimu',
#  'indy100',
#  'emperorzola',
#  'agung_amelia',
#  'themountica',
#  'cahwerneck',
#  'Visit_CostaRica',
#  'leappoffo',
#  'nycjim',
#  'jj_talking',
#  'newscomauHQ',
#  'ddsoffice',
#  'CNwadinigwe',
#  'WHOAFRO',
#  '3AM__MO',
#  'AFPphoto',
#  'TheOnion',
#  'MenPk1',
#  'SkyNewsBreak',
#  'AFP',
#  'BuzzFeedUK',
#  'WeatherBug',
#  'COVIDNewsByMIB',
#  'OpenParlyZw',
#  'dropeik',
#  'COfficialAremo',
#  'vdcl_001',
#  'SkyNewsAust',
#  'MANASA96592377',
#  'LijiPrince',
#  'Netcare911_sa',
#  'TommyT412',
#  'NickKristof',
#  'SKMCH',
#  'HuffPostUK',
#  'DailyMailAU',
#  'MSNBC',
#  'ExpediteLlp',
#  'latimes',
#  'MeteoKenya',
#  'AcrylicStroke',
#  'marspleb',
#  'SenatorBiaggi',
#  'thehill',
#  'JamaicaGleaner',
#  'oommen',
#  'nypost',
#  'ABC7',
#  'DLoesch',
#  'PennsylvaniaDEP',
#  'LifeNewsHQ',
#  'ForbesTech',
#  'CaribCardiac',
#  'infodemics1',
#  'Newsweek',
#  'Sabi2Earn',
#  'EW',
#  'F3_Haskell',
#  '_Krishna12',
#  'ClubFemina',
#  'ochealth',
#  'WHOPhilippines',
#  'getittogetherNG',
#  'UNGeneva',
#  'Jinxie_Al',
#  'LastGreatAct',
#  'Bipartisanism',
#  'bgghealthcare',
#  'NRF_SAASTA',
#  'rifaoorg',
#  'JaweriaNoor0',
#  'IngrahamAngle',
#  'ariana_lake',
#  'jciabujaunity',
#  'AllenWest',
#  'BurgerKing',
#  'nationalpost',
#  'KHOU',
#  'Reuters',
#  'molabus01']

# %%
len(source_multiple_tweet_users)
# Out:
# 156

# %%
single_name = 'Single or unseen user'
train_sources.loc[train_sources['user'].isin(source_multiple_tweet_users) == False, 'user'] = single_name
train_replies.loc[train_replies['user'].isin(replies_multiple_tweet_users) == False, 'user'] = single_name
dev_sources.loc[dev_sources['user'].isin(source_multiple_tweet_users) == False, 'user'] = single_name
dev_replies.loc[dev_replies['user'].isin(replies_multiple_tweet_users) == False, 'user'] = single_name
test_sources.loc[test_sources['user'].isin(source_multiple_tweet_users) == False, 'user'] = single_name
test_replies.loc[test_replies['user'].isin(replies_multiple_tweet_users) == False, 'user'] = single_name
train_sources
# Out:
#                          user verified   followers  \
# id
# 1218255692831903744       WHO     True  11173284.0
# 1218269428166602753       WHO     True  11173285.0
# 1219979825848442880       WHO     True  11173284.0
# 1219981282928668672       WHO     True  11173285.0
# 1219982106757148673       WHO     True  11173285.0
# ...                       ...      ...         ...
# 676367888543031296     nycjim     True    211869.0
# 676718762830221312    Complex     True   2574209.0
# 676870737932742656        ABC     True  17466165.0
# 677099574855639044        ABC     True  17466165.0
# 681767380305985536   mashable     True   9427476.0
#
#                                                                   text  \
# id
# 1218255692831903744  Is there a treatment for a novel coronavirus i...
# 1218269428166602753  What can I do to protect myself from coronavir...
# 1219979825848442880  Who are the members of an International Health...
# 1219981282928668672  How are the members of an International Health...
# 1219982106757148673  How are people appointed to the expert advisor...
# ...                                                                ...
# 676367888543031296   North Carolina town rejects solar panels for s...
# 676718762830221312   Texas plumber sues car dealership after his tr...
# 676870737932742656   Plumber suing car dealership for M after truck...
# 677099574855639044   Plumber suing car dealership for M after truck...
# 681767380305985536   Sorry Mark Zuckerberg is not giving billion to...
#
#                                                                 tokens  \
# id
# 1218255692831903744  [treatment, novel, coronavirus, infection, spe...
# 1218269428166602753                [protect, coronavirus, coronavirus]
# 1219979825848442880  [member, international, health, regulation, em...
# 1219981282928668672  [member, international, health, regulation, em...
# 1219982106757148673  [people, appoint, expert, advisory, panel, int...
# ...                                                                ...
# 676367888543031296   [north, carolina, town, reject, solar, panel, ...
# 676718762830221312   [texas, plumber, sue, car, dealership, truck, ...
# 676870737932742656   [plumber, sue, car, dealership, truck, trade, ...
# 677099574855639044   [plumber, sue, car, dealership, truck, trade, ...
# 681767380305985536   [sorry, mark, zuckerberg, give, billion, rando...
#
#                      retweets  favorites  statuses_count      hashtag  \
# id
# 1218255692831903744     202.0      265.0         69221.0  coronavirus
# 1218269428166602753    2007.0     2057.0         69221.0  coronavirus
# 1219979825848442880      20.0       43.0         69221.0  coronavirus
# 1219981282928668672      21.0       49.0         69221.0  coronavirus
# 1219982106757148673      19.0       44.0         69221.0  coronavirus
# ...                       ...        ...             ...          ...
# 676367888543031296      329.0      170.0        137128.0
# 676718762830221312      170.0      258.0        375499.0
# 676870737932742656      157.0       99.0        384381.0
# 677099574855639044      104.0       80.0        384381.0
# 681767380305985536       96.0       94.0        466664.0
#
#                          class  polarity
# id
# 1218255692831903744  nonrumour      0.25
# 1218269428166602753  nonrumour      0.00
# 1219979825848442880  nonrumour      0.00
# 1219981282928668672  nonrumour      0.00
# 1219982106757148673  nonrumour      0.00
# ...                        ...       ...
# 676367888543031296   nonrumour      0.00
# 676718762830221312      rumour      0.00
# 676870737932742656      rumour      0.00
# 677099574855639044      rumour      0.00
# 681767380305985536      rumour     -0.50
#
# [1561 rows x 11 columns]

# %% [markdown]
# **Feature Encoding**

# %%
def encode_df(df):
    encoded = df
    encoded['verified']=encoded['verified'].map({True:1, False:0})

    followers_encoded = []
    list_followers = list(encoded.followers)

    for n in list_followers:
        if n <1000:
            followers_encoded.append(1)
        elif n<5000:
            followers_encoded.append(2)
        elif n<20000:
            followers_encoded.append(3)
        elif n<50000:
            followers_encoded.append(4)
        elif n<200000:
            followers_encoded.append(5)
        else:
            followers_encoded.append(6)
        
    encoded.followers = followers_encoded
    
    return encoded

# %%
train_sources = encode_df(train_sources)
dev_sources = encode_df(dev_sources)
test_sources = encode_df(test_sources)
train_sources.head()
# Out:
#                     user  verified  followers  \
# id
# 1218255692831903744  WHO         1          6
# 1218269428166602753  WHO         1          6
# 1219979825848442880  WHO         1          6
# 1219981282928668672  WHO         1          6
# 1219982106757148673  WHO         1          6
#
#                                                                   text  \
# id
# 1218255692831903744  Is there a treatment for a novel coronavirus i...
# 1218269428166602753  What can I do to protect myself from coronavir...
# 1219979825848442880  Who are the members of an International Health...
# 1219981282928668672  How are the members of an International Health...
# 1219982106757148673  How are people appointed to the expert advisor...
#
#                                                                 tokens  \
# id
# 1218255692831903744  [treatment, novel, coronavirus, infection, spe...
# 1218269428166602753                [protect, coronavirus, coronavirus]
# 1219979825848442880  [member, international, health, regulation, em...
# 1219981282928668672  [member, international, health, regulation, em...
# 1219982106757148673  [people, appoint, expert, advisory, panel, int...
#
#                      retweets  favorites  statuses_count      hashtag  \
# id
# 1218255692831903744     202.0      265.0         69221.0  coronavirus
# 1218269428166602753    2007.0     2057.0         69221.0  coronavirus
# 1219979825848442880      20.0       43.0         69221.0  coronavirus
# 1219981282928668672      21.0       49.0         69221.0  coronavirus
# 1219982106757148673      19.0       44.0         69221.0  coronavirus
#
#                          class  polarity
# id
# 1218255692831903744  nonrumour      0.25
# 1218269428166602753  nonrumour      0.00
# 1219979825848442880  nonrumour      0.00
# 1219981282928668672  nonrumour      0.00
# 1219982106757148673  nonrumour      0.00

# %%
train_replies = encode_df(train_replies)
dev_replies = encode_df(dev_replies)
test_replies = encode_df(test_replies)
train_replies.head()
# Out:
#                           user  verified  followers  \
# id
# 1250219116993974272  ucoptempe         0          1
# 1250219437027766273  ucoptempe         0          1
# 1250219620939657216  ucoptempe         0          1
# 1250219777185873922  ucoptempe         0          1
# 1250219894429208577  ucoptempe         0          1
#
#                                                                   text  \
# id
# 1250219116993974272  Can eating garlic help prevent infection with ...
# 1250219437027766273  Do vaccines against pneumonia protect you agai...
# 1250219620939657216  Can spraying alcohol or chlorine all over your...
# 1250219777185873922  How effective are thermal scanners in detectin...
# 1250219894429208577  Can an ultraviolet disinfection lamp kill the ...
#
#                                                                 tokens  \
# id
# 1250219116993974272  [eat, garlic, help, prevent, infection, new, c...
# 1250219437027766273    [vaccine, pneumonia, protect, new, coronavirus]
# 1250219620939657216  [spray, alcohol, chlorine, body, kill, new, co...
# 1250219777185873922  [effective, thermal, scanner, detect, people, ...
# 1250219894429208577  [ultraviolet, disinfection, lamp, kill, new, c...
#
#                      retweets  favorites  statuses_count          hashtag  \
# id
# 1250219116993974272         0          0           26613  COVID19Malaysia
# 1250219437027766273         0          0           26613
# 1250219620939657216         0          0           26613          Chamber
# 1250219777185873922         0          0           26613
# 1250219894429208577         0          0           26613
#
#                                source id source class  polarity
# id
# 1250219116993974272  1250219300389974016    nonrumour  0.136364
# 1250219437027766273  1250219300389974016    nonrumour  0.136364
# 1250219620939657216  1250219300389974016    nonrumour  0.136364
# 1250219777185873922  1250219300389974016    nonrumour  0.368182
# 1250219894429208577  1250219300389974016    nonrumour  0.136364

# %%
train_sources.drop(['text','hashtag'],axis=1,inplace=True)
dev_sources.drop(['text','hashtag'],axis=1,inplace=True)
test_sources.drop(['text','hashtag'],axis=1,inplace=True)
train_sources
# Out:
#                          user  verified  followers  \
# id
# 1218255692831903744       WHO         1          6
# 1218269428166602753       WHO         1          6
# 1219979825848442880       WHO         1          6
# 1219981282928668672       WHO         1          6
# 1219982106757148673       WHO         1          6
# ...                       ...       ...        ...
# 676367888543031296     nycjim         1          6
# 676718762830221312    Complex         1          6
# 676870737932742656        ABC         1          6
# 677099574855639044        ABC         1          6
# 681767380305985536   mashable         1          6
#
#                                                                 tokens  \
# id
# 1218255692831903744  [treatment, novel, coronavirus, infection, spe...
# 1218269428166602753                [protect, coronavirus, coronavirus]
# 1219979825848442880  [member, international, health, regulation, em...
# 1219981282928668672  [member, international, health, regulation, em...
# 1219982106757148673  [people, appoint, expert, advisory, panel, int...
# ...                                                                ...
# 676367888543031296   [north, carolina, town, reject, solar, panel, ...
# 676718762830221312   [texas, plumber, sue, car, dealership, truck, ...
# 676870737932742656   [plumber, sue, car, dealership, truck, trade, ...
# 677099574855639044   [plumber, sue, car, dealership, truck, trade, ...
# 681767380305985536   [sorry, mark, zuckerberg, give, billion, rando...
#
#                      retweets  favorites  statuses_count      class  polarity
# id
# 1218255692831903744     202.0      265.0         69221.0  nonrumour      0.25
# 1218269428166602753    2007.0     2057.0         69221.0  nonrumour      0.00
# 1219979825848442880      20.0       43.0         69221.0  nonrumour      0.00
# 1219981282928668672      21.0       49.0         69221.0  nonrumour      0.00
# 1219982106757148673      19.0       44.0         69221.0  nonrumour      0.00
# ...                       ...        ...             ...        ...       ...
# 676367888543031296      329.0      170.0        137128.0  nonrumour      0.00
# 676718762830221312      170.0      258.0        375499.0     rumour      0.00
# 676870737932742656      157.0       99.0        384381.0     rumour      0.00
# 677099574855639044      104.0       80.0        384381.0     rumour      0.00
# 681767380305985536       96.0       94.0        466664.0     rumour     -0.50
#
# [1561 rows x 9 columns]

# %%
train_replies.drop(['text','hashtag','source id'],axis=1,inplace=True)
dev_replies.drop(['text','hashtag','source id'],axis=1,inplace=True)
test_replies.drop(['text','hashtag'],axis=1,inplace=True)
train_replies
# Out:
#                              user  verified  followers  \
# id
# 1250219116993974272     ucoptempe         0          1
# 1250219437027766273     ucoptempe         0          1
# 1250219620939657216     ucoptempe         0          1
# 1250219777185873922     ucoptempe         0          1
# 1250219894429208577     ucoptempe         0          1
# ...                           ...       ...        ...
# 1241078443179155457  lynneSimpkin         0          1
# 1241085785060847617  lynneSimpkin         0          1
# 1241086391267872770    rosierawle         0          2
# 1241086505566732289  lynneSimpkin         0          1
# 1241086382875033600  lynneSimpkin         0          1
#
#                                                                 tokens  \
# id
# 1250219116993974272  [eat, garlic, help, prevent, infection, new, c...
# 1250219437027766273    [vaccine, pneumonia, protect, new, coronavirus]
# 1250219620939657216  [spray, alcohol, chlorine, body, kill, new, co...
# 1250219777185873922  [effective, thermal, scanner, detect, people, ...
# 1250219894429208577  [ultraviolet, disinfection, lamp, kill, new, c...
# ...                                                                ...
# 1241078443179155457         [good, work, new, home, school, timetable]
# 1241085785060847617  [best, timetable, ive, hear, minecraft, bad, r...
# 1241086391267872770                 [exactly, need, come, class, haha]
# 1241086505566732289                     [might, send, twice, accident]
# 1241086382875033600  [best, timetable, yet, minecraft, bore, respec...
#
#                      retweets  favorites  statuses_count source class  \
# id
# 1250219116993974272         0          0           26613    nonrumour
# 1250219437027766273         0          0           26613    nonrumour
# 1250219620939657216         0          0           26613    nonrumour
# 1250219777185873922         0          0           26613    nonrumour
# 1250219894429208577         0          0           26613    nonrumour
# ...                       ...        ...             ...          ...
# 1241078443179155457         0          1            5118    nonrumour
# 1241085785060847617         0          1            5118    nonrumour
# 1241086391267872770         0          1            5507    nonrumour
# 1241086505566732289         0          1            5118    nonrumour
# 1241086382875033600         0          0            5118    nonrumour
#
#                      polarity
# id
# 1250219116993974272  0.136364
# 1250219437027766273  0.136364
# 1250219620939657216  0.136364
# 1250219777185873922  0.368182
# 1250219894429208577  0.136364
# ...                       ...
# 1241078443179155457  0.418182
# 1241085785060847617 -0.066667
# 1241086391267872770  0.225000
# 1241086505566732289  0.000000
# 1241086382875033600 -0.166667
#
# [28485 rows x 9 columns]

# %%
def count_tokens(df):
    token_counts = {}
    for token_list in list(df['tokens']):
        for token in token_list:
            if token in token_counts:
                token_counts[token] += 1
            else:
                token_counts[token] = 1
    return {k: v for k, v in sorted(token_counts.items(), key=lambda item: item[1],reverse=True)}
            
replies_uni_counts = count_tokens(train_replies)
source_uni_counts = count_tokens(train_sources)
replies_uni_counts
# Out:
# {'covid': 2338,
#  'coronavirus': 2237,
#  'people': 1976,
#  'new': 1668,
#  'get': 1275,
#  'like': 1197,
#  'virus': 1104,
#  'say': 1101,
#  'dont': 1014,
#  'go': 1005,
#  'make': 917,
#  'one': 914,
#  'know': 881,
#  'u': 814,
#  'think': 792,
#  'rt': 768,
#  'would': 737,
#  'need': 732,
#  'see': 712,
#  'good': 702,
#  'take': 669,
#  'kill': 635,
#  'im': 635,
#  'thats': 632,
#  'test': 628,
#  'time': 606,
#  'prevent': 605,
#  'work': 603,
#  'hand': 598,
#  'day': 554,
#  'die': 547,
#  'use': 530,
#  'spread': 527,
#  'someone': 520,
#  'spider': 513,
#  'disease': 507,
#  'care': 501,
#  'death': 491,
#  'give': 487,
#  'want': 477,
#  'look': 476,
#  'come': 473,
#  'even': 460,
#  'still': 444,
#  'right': 444,
#  'protect': 440,
#  'person': 435,
#  'stop': 433,
#  'report': 432,
#  'infect': 429,
#  'help': 424,
#  'infection': 420,
#  'thank': 419,
#  'treat': 418,
#  'find': 417,
#  'really': 414,
#  'case': 410,
#  'million': 410,
#  'well': 404,
#  'way': 403,
#  'news': 400,
#  'wear': 400,
#  'may': 396,
#  'woman': 395,
#  'fuck': 388,
#  'oh': 383,
#  '19': 379,
#  'thing': 377,
#  'paul': 375,
#  'spray': 374,
#  'god': 371,
#  'symptom': 364,
#  'country': 363,
#  'lol': 359,
#  'president': 357,
#  'cant': 353,
#  'home': 350,
#  'walker': 349,
#  'love': 348,
#  'also': 347,
#  'let': 345,
#  'world': 344,
#  'cough': 339,
#  'complexmag': 339,
#  'mask': 336,
#  'obama': 334,
#  'first': 334,
#  'sad': 332,
#  'ncov': 332,
#  'shoot': 329,
#  'call': 329,
#  'much': 328,
#  'break': 328,
#  'rip': 327,
#  'cause': 327,
#  'mean': 326,
#  'vaccine': 323,
#  'true': 321,
#  'puppysized': 320,
#  'show': 317,
#  'effective': 314,
#  'tell': 314,
#  'many': 314,
#  'please': 314,
#  'man': 309,
#  'back': 304,
#  'stay': 302,
#  'health': 300,
#  'become': 300,
#  'could': 300,
#  'surprise': 299,
#  'live': 299,
#  'sure': 296,
#  'put': 296,
#  'penis': 295,
#  'try': 293,
#  'happen': 290,
#  'real': 290,
#  'scientist': 288,
#  'nose': 287,
#  'eat': 286,
#  'water': 286,
#  'china': 285,
#  'bugatti': 285,
#  'year': 285,
#  'doesnt': 283,
#  'sick': 283,
#  'yes': 282,
#  'paint': 282,
#  'white': 280,
#  'keep': 279,
#  'life': 277,
#  'follow': 277,
#  'specific': 275,
#  'better': 275,
#  'believe': 275,
#  'fact': 272,
#  'florida': 267,
#  'police': 266,
#  'veyron': 266,
#  'family': 263,
#  'guy': 262,
#  'around': 262,
#  'rainforest': 258,
#  'hope': 257,
#  'catch': 256,
#  'medicine': 252,
#  'isi': 252,
#  'wow': 248,
#  'last': 248,
#  'trump': 247,
#  'didnt': 245,
#  'everyone': 245,
#  'th': 245,
#  'feel': 244,
#  'body': 239,
#  'great': 239,
#  'third': 238,
#  'shit': 235,
#  'number': 233,
#  'la': 232,
#  'word': 232,
#  'daughter': 231,
#  'book': 230,
#  'part': 229,
#  'safe': 227,
#  'big': 224,
#  'leave': 224,
#  'wtf': 223,
#  'wont': 223,
#  'respiratory': 223,
#  'iphone': 223,
#  'evidence': 222,
#  'wash': 222,
#  'pay': 222,
#  'confirm': 221,
#  'never': 220,
#  'nhl': 220,
#  'food': 219,
#  'something': 219,
#  'dead': 218,
#  'seem': 216,
#  'hot': 215,
#  'maybe': 215,
#  'black': 214,
#  'antibiotic': 213,
#  'transmit': 211,
#  'however': 210,
#  'do': 209,
#  'city': 207,
#  'yet': 206,
#  'droplet': 206,
#  'read': 203,
#  'harry': 203,
#  'isnt': 201,
#  'touch': 200,
#  'hell': 199,
#  'kid': 199,
#  'south': 198,
#  'buzzfeed': 198,
#  'medical': 197,
#  'receive': 197,
#  'long': 197,
#  'pro': 197,
#  'state': 196,
#  'photo': 196,
#  'era': 196,
#  'must': 195,
#  'add': 195,
#  'talk': 195,
#  'affect': 194,
#  'risk': 194,
#  'youre': 194,
#  'week': 194,
#  'gun': 192,
#  'potter': 192,
#  'wrong': 191,
#  'without': 189,
#  'obamas': 188,
#  'hear': 188,
#  'team': 188,
#  'vega': 188,
#  'government': 187,
#  'bad': 186,
#  'house': 186,
#  'dog': 185,
#  'ferguson': 184,
#  'develop': 184,
#  'mouth': 184,
#  'fever': 183,
#  'ok': 183,
#  'fake': 182,
#  'he': 182,
#  'wasnt': 182,
#  'expansion': 182,
#  'tshirt': 181,
#  'include': 180,
#  'watch': 180,
#  'ill': 179,
#  'source': 179,
#  'human': 178,
#  'jk': 178,
#  'rowling': 178,
#  'area': 177,
#  'ever': 177,
#  'problem': 177,
#  'since': 177,
#  'bend': 176,
#  'pocket': 175,
#  'immunity': 175,
#  'two': 174,
#  'dew': 174,
#  'ban': 173,
#  'fast': 173,
#  'place': 173,
#  'tweet': 173,
#  'nope': 173,
#  'surface': 172,
#  'public': 172,
#  'hostage': 172,
#  'contact': 170,
#  'money': 170,
#  'older': 168,
#  'every': 168,
#  'muslim': 167,
#  'ask': 167,
#  'anything': 166,
#  'start': 166,
#  'child': 166,
#  'mountain': 166,
#  'g': 165,
#  'outbreak': 165,
#  'soldier': 165,
#  'surgery': 165,
#  'whats': 164,
#  'treatment': 163,
#  'another': 162,
#  'video': 162,
#  'breathe': 161,
#  'enough': 161,
#  'run': 161,
#  'lie': 161,
#  'alcohol': 160,
#  'clean': 160,
#  'issue': 160,
#  'cnn': 160,
#  'others': 159,
#  'change': 159,
#  'animal': 158,
#  'regularly': 157,
#  'soon': 157,
#  'stupid': 157,
#  'heart': 156,
#  'actually': 155,
#  'buy': 155,
#  'send': 154,
#  'wonder': 154,
#  'save': 154,
#  'name': 153,
#  'eye': 153,
#  'guess': 152,
#  'lot': 152,
#  'best': 152,
#  'flu': 152,
#  'question': 151,
#  'meet': 151,
#  'nothing': 150,
#  'yeah': 150,
#  'le': 150,
#  'bite': 149,
#  'free': 149,
#  'information': 149,
#  'support': 149,
#  'law': 149,
#  'already': 148,
#  'update': 148,
#  'medium': 148,
#  'hoax': 148,
#  'frediboat': 148,
#  'eonline': 148,
#  'face': 147,
#  'war': 147,
#  'job': 146,
#  'doritosflavored': 146,
#  'severe': 145,
#  'boob': 145,
#  'next': 144,
#  'alive': 144,
#  'jail': 144,
#  'garlic': 143,
#  'check': 143,
#  'possible': 142,
#  'today': 142,
#  'manager': 141,
#  'myth': 140,
#  'away': 139,
#  'b': 139,
#  'close': 139,
#  'wait': 139,
#  'story': 139,
#  'chickfila': 139,
#  'date': 138,
#  'understand': 138,
#  'gay': 138,
#  'deal': 137,
#  'usa': 136,
#  'star': 136,
#  'probably': 135,
#  'least': 135,
#  'system': 135,
#  'old': 135,
#  'point': 134,
#  'exactly': 134,
#  'reportedly': 134,
#  'cannot': 133,
#  'share': 133,
#  'driver': 133,
#  'unrevealedfacts': 133,
#  'rest': 131,
#  'control': 130,
#  'end': 130,
#  'illness': 130,
#  'might': 130,
#  'allow': 130,
#  'cold': 129,
#  'r': 129,
#  'n': 128,
#  'air': 128,
#  'terrorist': 127,
#  'play': 127,
#  'avoid': 127,
#  'bring': 127,
#  'important': 126,
#  'data': 126,
#  'far': 124,
#  'idea': 124,
#  'anyone': 124,
#  'fight': 124,
#  'common': 123,
#  'sound': 123,
#  'hate': 123,
#  'xxl': 123,
#  'pneumonia': 122,
#  'recommend': 122,
#  'member': 122,
#  'tv': 122,
#  'there': 121,
#  'age': 121,
#  'soap': 121,
#  'fall': 121,
#  'damn': 120,
#  'reason': 120,
#  'light': 120,
#  'taste': 120,
#  'though': 119,
#  'drink': 118,
#  'theyre': 118,
#  'id': 118,
#  'corona': 117,
#  'patient': 117,
#  'omg': 117,
#  'goliath': 117,
#  'detect': 116,
#  'rinse': 116,
#  'w': 116,
#  'plan': 116,
#  'sneeze': 116,
#  'likely': 115,
#  'deer': 115,
#  'national': 114,
#  'plus': 114,
#  'furious': 114,
#  'school': 114,
#  'ive': 114,
#  'serious': 113,
#  'positive': 113,
#  'link': 113,
#  'ago': 113,
#  'starbucks': 113,
#  'puppy': 113,
#  'hold': 111,
#  'little': 111,
#  'arrest': 110,
#  'size': 110,
#  'bank': 110,
#  'banksy': 110,
#  'high': 109,
#  'claim': 109,
#  'result': 109,
#  'cover': 109,
#  'ottawa': 107,
#  'different': 107,
#  'everything': 107,
#  'miss': 107,
#  'via': 107,
#  'louisiana': 107,
#  'charliehebdo': 106,
#  'info': 106,
#  'birdeater': 106,
#  'fakenews': 106,
#  'attack': 105,
#  'whole': 105,
#  'build': 105,
#  'chicken': 105,
#  'joke': 105,
#  'mh': 105,
#  'recover': 104,
#  'distance': 104,
#  'employee': 104,
#  'move': 103,
#  'condition': 103,
#  'always': 103,
#  'mt': 103,
#  'herd': 103,
#  'reality': 103,
#  'movie': 103,
#  'hour': 103,
#  'saline': 102,
#  'open': 102,
#  'de': 102,
#  'famous': 102,
#  'suspect': 101,
#  'type': 101,
#  'idiot': 101,
#  'canadian': 100,
#  'car': 100,
#  'cop': 100,
#  'evil': 100,
#  'ppl': 100,
#  'friend': 100,
#  'antibody': 100,
#  'twerking': 100,
#  'susceptible': 99,
#  'research': 99,
#  'social': 99,
#  'lose': 99,
#  'release': 99,
#  'answer': 99,
#  'phone': 99,
#  'list': 99,
#  'travel': 98,
#  'canada': 98,
#  'situation': 98,
#  'yall': 98,
#  'disgust': 98,
#  'difficulty': 97,
#  'memorial': 97,
#  'official': 97,
#  'nurse': 97,
#  'uk': 97,
#  'post': 97,
#  'chlorine': 96,
#  'weather': 96,
#  'turn': 96,
#  'study': 96,
#  'kind': 96,
#  'saw': 96,
#  'provide': 95,
#  'behead': 95,
#  'hospital': 95,
#  'gonna': 95,
#  'letter': 94,
#  'interest': 94,
#  'funny': 94,
#  'crazy': 94,
#  'article': 94,
#  'night': 94,
#  'pope': 94,
#  'slang': 94,
#  'healthy': 93,
#  'act': 93,
#  'parent': 93,
#  'learn': 93,
#  'measure': 93,
#  'fire': 93,
#  'lord': 93,
#  'toronto': 93,
#  'younger': 92,
#  'package': 92,
#  'poor': 92,
#  'month': 92,
#  'hard': 92,
#  'latte': 92,
#  'girl': 91,
#  'foxnews': 91,
#  'hank': 91,
#  'guinness': 91,
#  'step': 90,
#  'remember': 90,
#  'begin': 89,
#  'low': 89,
#  'peace': 89,
#  'order': 89,
#  'lego': 89,
#  'breast': 89,
#  'temperature': 88,
#  'sweet': 88,
#  'kkk': 88,
#  'seattle': 88,
#  'surgically': 88,
#  'record': 87,
#  'shut': 87,
#  'pretty': 87,
#  'shooter': 87,
#  'second': 86,
#  'false': 86,
#  'coronaviruses': 86,
#  'gang': 86,
#  'agree': 86,
#  'wouldnt': 86,
#  'hello': 86,
#  'pandemic': 86,
#  'pepsi': 86,
#  'mh17': 86,
#  'stand': 85,
#  'base': 85,
#  'ya': 84,
#  'mild': 84,
#  'seriously': 84,
#  'rate': 84,
#  'fxnscitech': 84,
#  'three': 83,
#  'early': 83,
#  'appear': 83,
#  'blood': 83,
#  'sars': 83,
#  'vote': 83,
#  'expect': 83,
#  'mind': 83,
#  'consider': 83,
#  'gunman': 83,
#  'sydney': 83,
#  'bid': 83,
#  'higher': 82,
#  'pet': 82,
#  'sorry': 82,
#  'example': 82,
#  'small': 82,
#  'sit': 82,
#  'happy': 82,
#  'owner': 82,
#  'total': 82,
#  'racist': 82,
#  'scanner': 81,
#  'discover': 81,
#  'protection': 81,
#  'sleep': 81,
#  'paris': 81,
#  'men': 81,
#  'thermal': 80,
#  'islam': 80,
#  'mashable': 80,
#  'diabetes': 80,
#  'suggest': 80,
#  'young': 80,
#  'pop': 80,
#  'action': 79,
#  'lmao': 79,
#  'website': 79,
#  'burgerking': 79,
#  'seek': 78,
#  'experience': 78,
#  'italy': 78,
#  'continue': 78,
#  'e': 78,
#  'nice': 77,
#  'instead': 77,
#  'etc': 77,
#  'head': 77,
#  'x': 77,
#  'picture': 77,
#  'truth': 77,
#  'govt': 77,
#  'fail': 77,
#  'able': 76,
#  'hey': 76,
#  'frequently': 76,
#  'wish': 76,
#  'prayer': 76,
#  'sign': 76,
#  'c': 75,
#  'smh': 75,
#  'alcoholbased': 75,
#  'que': 75,
#  'beautiful': 75,
#  'speak': 75,
#  'trust': 75,
#  'k': 75,
#  'sugarhill': 75,
#  'mythbusters': 75,
#  'enter': 74,
#  'rub': 74,
#  'doctor': 74,
#  'flag': 73,
#  'current': 73,
#  'sydneysiege': 73,
#  'pregnant': 73,
#  'wuhan': 73,
#  'lockdown': 73,
#  'destroy': 73,
#  'spot': 73,
#  'shame': 73,
#  'group': 73,
#  'mom': 73,
#  'listen': 72,
#  'recall': 72,
#  'lamp': 71,
#  'bear': 71,
#  'simple': 71,
#  'as': 71,
#  'decision': 71,
#  'skin': 71,
#  'punishment': 71,
#  'rainbow': 71,
#  'climate': 70,
#  'sense': 70,
#  'drug': 70,
#  'else': 70,
#  'matter': 70,
#  'party': 70,
#  'boy': 70,
#  'dailymail': 70,
#  'survive': 69,
#  'victim': 69,
#  'arent': 69,
#  'economy': 69,
#  'fanged': 69,
#  'refugee': 69,
#  'dangerous': 68,
#  'expose': 68,
#  'plane': 68,
#  'tragic': 68,
#  'choose': 68,
#  'worker': 68,
#  'fear': 68,
#  'factcheck': 68,
#  'scrap': 68,
#  'breakfast': 67,
#  'several': 67,
#  'course': 67,
#  'europe': 67,
#  'hygiene': 67,
#  'full': 67,
#  'tcot': 67,
#  'hi': 67,
#  'oil': 66,
#  'lead': 66,
#  'company': 66,
#  'rule': 66,
#  'highly': 66,
#  'twitter': 66,
#  'practice': 66,
#  'absolutely': 66,
#  'fee': 66,
#  'near': 66,
#  'bringbackourgirls': 66,
#  'shouldnt': 65,
#  'di': 65,
#  'force': 65,
#  'buster': 65,
#  'sell': 65,
#  'transmission': 65,
#  'finally': 65,
#  'burn': 65,
#  'set': 65,
#  'delay': 65,
#  'dryer': 64,
#  'rather': 64,
#  'david': 64,
#  'influenza': 64,
#  'murder': 64,
#  'cut': 64,
#  'worry': 64,
#  'kfc': 64,
#  'ebola': 64,
#  'grow': 64,
#  'illegal': 64,
#  'yr': 64,
#  'bet': 63,
#  'choice': 63,
#  'immediately': 63,
#  'parliament': 63,
#  'game': 63,
#  'expert': 63,
#  'leader': 63,
#  'local': 63,
#  'prove': 63,
#  'create': 63,
#  'havent': 63,
#  'church': 63,
#  'belong': 63,
#  'pourmecoffee': 63,
#  'mosquito': 62,
#  'pray': 62,
#  'mention': 62,
#  'rippaulwalker': 62,
#  'individual': 62,
#  'islamic': 62,
#  'either': 62,
#  'amaze': 62,
#  'remain': 62,
#  'meat': 62,
#  'authority': 62,
#  'gross': 62,
#  'walmart': 62,
#  'foxphilly': 62,
#  'impose': 62,
#  'humid': 61,
#  'lung': 61,
#  'network': 61,
#  'object': 61,
#  'therefore': 61,
#  'concern': 61,
#  'science': 61,
#  'appropriate': 61,
#  'physical': 61,
#  'el': 61,
#  'proof': 61,
#  'draw': 61,
#  'pumpkin': 61,
#  'behind': 60,
#  'ur': 60,
#  'independent': 60,
#  'especially': 60,
#  'worst': 60,
#  'aint': 60,
#  'walk': 60,
#  'newcrownvirus': 60,
#  'abandon': 60,
#  'range': 59,
#  'color': 59,
#  'special': 59,
#  'military': 59,
#  'rat': 59,
#  'population': 59,
#  'exist': 59,
#  'large': 59,
#  'tissue': 59,
#  'advice': 59,
#  'late': 59,
#  'fry': 59,
#  'jesus': 59,
#  'respect': 59,
#  'due': 59,
#  'message': 59,
#  'poll': 59,
#  'cell': 59,
#  'reaitupac': 59,
#  'knowthefacts': 58,
#  'middle': 58,
#  'suck': 58,
#  'business': 58,
#  'reduce': 58,
#  'prevention': 58,
#  'sir': 58,
#  'wake': 58,
#  'hit': 58,
#  'fukushima': 58,
#  'passenger': 58,
#  'drive': 57,
#  'inside': 57,
#  'baby': 57,
#  'pick': 57,
#  'thread': 57,
#  'feature': 57,
#  'crap': 57,
#  'visit': 57,
#  'holy': 57,
#  'hillary': 57,
#  'shes': 57,
#  'obviously': 56,
#  'history': 56,
#  'foot': 56,
#  'citizen': 56,
#  'station': 56,
#  'interview': 56,
#  'available': 56,
#  'freedom': 56,
#  'top': 56,
#  'texas': 56,
#  'tmz': 56,
#  'immune': 56,
#  'response': 56,
#  'offense': 56,
#  'charlie': 55,
#  'bless': 55,
#  'chance': 55,
#  'throw': 55,
#  'site': 55,
#  'increase': 55,
#  'earth': 55,
#  'staff': 55,
#  'attention': 55,
#  'dewitos': 55,
#  'condom': 55,
#  'putin': 54,
#  'comment': 54,
#  'panic': 54,
#  'explain': 54,
#  'alone': 54,
#  'period': 54,
#  'shock': 54,
#  'ridiculous': 54,
#  'write': 54,
#  'raise': 54,
#  'view': 54,
#  'radioactive': 54,
#  'openparlyzw': 54,
#  'katrinalome': 54,
#  'bath': 53,
#  'vulnerable': 53,
#  'contract': 53,
#  'yang': 53,
#  'dude': 53,
#  'dear': 53,
#  'em': 53,
#  'st': 53,
#  'worse': 53,
#  'paper': 53,
#  'bacteria': 53,
#  'join': 53,
#  'mandatory': 53,
#  'na': 53,
#  'spam': 53,
#  'hop': 53,
#  'powerful': 53,
#  'crash': 53,
#  'spice': 53,
#  'wilson': 53,
#  'huffingtonpost': 53,
#  'effort': 52,
#  'level': 52,
#  'charge': 52,
#  'limit': 52,
#  'cool': 52,
#  'red': 52,
#  'clear': 52,
#  'malia': 52,
#  'uberfacts': 52,
#  'fakebuster': 52,
#  'hoaxorfact': 52,
#  'hoaxnews': 52,
#  'factcheckindia': 52,
#  'viralnews': 52,
#  'fakeviral': 52,
#  'fakecorona': 52,
#  'hebdo': 51,
#  'totally': 51,
#  'ottawashooting': 51,
#  'wipe': 51,
#  'warn': 51,
#  'return': 51,
#  'stuff': 51,
#  'violence': 51,
#  'bk': 51,
#  'disinfection': 50,
#  'v': 50,
#  'non': 50,
#  'fund': 50,
#  'pas': 50,
#  'community': 50,
#  'bullshit': 50,
#  'glad': 50,
#  'huh': 50,
#  'donation': 50,
#  'event': 50,
#  'haha': 50,
#  'stab': 50,
#  'stephen': 50,
#  'bestpronews': 50,
#  'mobile': 49,
#  'preexist': 49,
#  '2019ncov': 49,
#  'da': 49,
#  'suppose': 49,
#  'service': 49,
#  'effect': 49,
#  'together': 49,
#  'boycott': 49,
#  'variety': 49,
#  'emergency': 49,
#  'internet': 49,
#  'cafe': 49,
#  'durex': 49,
#  'jamie': 49,
#  'hip': 49,
#  'breath': 48,
#  'terrible': 48,
#  'blame': 48,
#  'riot': 48,
#  'advise': 48,
#  'cure': 48,
#  'supportive': 48,
#  'power': 48,
#  'weve': 48,
#  'declare': 48,
#  'tax': 48,
#  'waste': 48,
#  'deny': 48,
#  'scar': 48,
#  'correct': 48,
#  'gt': 48,
#  'scary': 48,
#  'cancer': 48,
#  'liberal': 48,
#  'ultraviolet': 47,
#  'horrible': 47,
#  'cdc': 47,
#  'present': 47,
#  'race': 47,
#  'daily': 47,
#  'main': 47,
#  'latest': 47,
#  'rumor': 47,
#  'negative': 47,
#  'en': 47,
#  'market': 47,
#  'governor': 47,
#  'bruh': 47,
#  'hood': 47,
#  'land': 46,
#  'rid': 46,
#  'forget': 46,
#  'syndrome': 46,
#  'unite': 46,
#  'strong': 46,
#  'chinese': 46,
#  'nestl': 46,
#  'value': 46,
#  'four': 46,
#  'nigeria': 46,
#  'ibuprofen': 46,
#  'meter': 45,
#  'global': 45,
#  'thought': 45,
#  'price': 45,
#  'normal': 45,
#  'relieve': 45,
#  'almost': 45,
#  'anyway': 45,
#  'yesterday': 45,
#  'mass': 45,
#  'border': 45,
#  'okay': 45,
#  'till': 45,
#  'train': 45,
#  'ukraine': 45,
#  'compare': 45,
#  'suicide': 44,
#  'novel': 44,
#  'protest': 44,
#  'gop': 44,
#  'office': 44,
#  'piss': 44,
#  'infectious': 44,
#  'ahead': 44,
#  'pic': 44,
#  'product': 44,
#  'trial': 44,
#  'fan': 44,
#  ...}

# %% [markdown]
# Create new columns for token one-hot encoding

# %%
source_top_tokens = list(source_uni_counts.keys())[0:500]

new_cols = [x for x in list(train_sources.columns) if x != 'class'] + source_top_tokens + ['class']
train_sources = train_sources.reindex(columns=new_cols, fill_value=0)
dev_sources = dev_sources.reindex(columns=new_cols, fill_value=0)
test_sources = test_sources.reindex(columns=new_cols, fill_value=0)
train_sources.head()
# Out:
#                     user  verified  followers  \
# id
# 1218255692831903744  WHO         1          6
# 1218269428166602753  WHO         1          6
# 1219979825848442880  WHO         1          6
# 1219981282928668672  WHO         1          6
# 1219982106757148673  WHO         1          6
#
#                                                                 tokens  \
# id
# 1218255692831903744  [treatment, novel, coronavirus, infection, spe...
# 1218269428166602753                [protect, coronavirus, coronavirus]
# 1219979825848442880  [member, international, health, regulation, em...
# 1219981282928668672  [member, international, health, regulation, em...
# 1219982106757148673  [people, appoint, expert, advisory, panel, int...
#
#                      retweets  favorites  statuses_count  polarity  covid  \
# id
# 1218255692831903744     202.0      265.0         69221.0      0.25      0
# 1218269428166602753    2007.0     2057.0         69221.0      0.00      0
# 1219979825848442880      20.0       43.0         69221.0      0.00      0
# 1219981282928668672      21.0       49.0         69221.0      0.00      0
# 1219982106757148673      19.0       44.0         69221.0      0.00      0
#
#                      coronavirus  ...  extremely  frediboat  likely  \
# id                                ...
# 1218255692831903744            0  ...          0          0       0
# 1218269428166602753            0  ...          0          0       0
# 1219979825848442880            0  ...          0          0       0
# 1219981282928668672            0  ...          0          0       0
# 1219982106757148673            0  ...          0          0       0
#
#                      coronavirusupdates  bad  coronafreepakistan  th  sir  \
# id
# 1218255692831903744                   0    0                   0   0    0
# 1218269428166602753                   0    0                   0   0    0
# 1219979825848442880                   0    0                   0   0    0
# 1219981282928668672                   0    0                   0   0    0
# 1219982106757148673                   0    0                   0   0    0
#
#                      wrong      class
# id
# 1218255692831903744      0  nonrumour
# 1218269428166602753      0  nonrumour
# 1219979825848442880      0  nonrumour
# 1219981282928668672      0  nonrumour
# 1219982106757148673      0  nonrumour
#
# [5 rows x 509 columns]

# %%
reply_top_tokens = list(replies_uni_counts.keys())[0:500]

new_cols = [x for x in list(train_replies.columns) if x != 'source class']+ reply_top_tokens +['source class']
train_replies = train_replies.reindex(columns=new_cols, fill_value=0)
dev_replies = dev_replies.reindex(columns=new_cols, fill_value=0)
test_replies = test_replies.reindex(columns=new_cols, fill_value=0)
train_replies
# Out:
#                              user  verified  followers  \
# id
# 1250219116993974272     ucoptempe         0          1
# 1250219437027766273     ucoptempe         0          1
# 1250219620939657216     ucoptempe         0          1
# 1250219777185873922     ucoptempe         0          1
# 1250219894429208577     ucoptempe         0          1
# ...                           ...       ...        ...
# 1241078443179155457  lynneSimpkin         0          1
# 1241085785060847617  lynneSimpkin         0          1
# 1241086391267872770    rosierawle         0          2
# 1241086505566732289  lynneSimpkin         0          1
# 1241086382875033600  lynneSimpkin         0          1
#
#                                                                 tokens  \
# id
# 1250219116993974272  [eat, garlic, help, prevent, infection, new, c...
# 1250219437027766273    [vaccine, pneumonia, protect, new, coronavirus]
# 1250219620939657216  [spray, alcohol, chlorine, body, kill, new, co...
# 1250219777185873922  [effective, thermal, scanner, detect, people, ...
# 1250219894429208577  [ultraviolet, disinfection, lamp, kill, new, c...
# ...                                                                ...
# 1241078443179155457         [good, work, new, home, school, timetable]
# 1241085785060847617  [best, timetable, ive, hear, minecraft, bad, r...
# 1241086391267872770                 [exactly, need, come, class, haha]
# 1241086505566732289                     [might, send, twice, accident]
# 1241086382875033600  [best, timetable, yet, minecraft, bore, respec...
#
#                      retweets  favorites  statuses_count  polarity  covid  \
# id
# 1250219116993974272         0          0           26613  0.136364      0
# 1250219437027766273         0          0           26613  0.136364      0
# 1250219620939657216         0          0           26613  0.136364      0
# 1250219777185873922         0          0           26613  0.368182      0
# 1250219894429208577         0          0           26613  0.136364      0
# ...                       ...        ...             ...       ...    ...
# 1241078443179155457         0          1            5118  0.418182      0
# 1241085785060847617         0          1            5118 -0.066667      0
# 1241086391267872770         0          1            5507  0.225000      0
# 1241086505566732289         0          1            5118  0.000000      0
# 1241086382875033600         0          0            5118 -0.166667      0
#
#                      coronavirus  ...  chlorine  weather  turn  study  kind  \
# id                                ...
# 1250219116993974272            0  ...         0        0     0      0     0
# 1250219437027766273            0  ...         0        0     0      0     0
# 1250219620939657216            0  ...         0        0     0      0     0
# 1250219777185873922            0  ...         0        0     0      0     0
# 1250219894429208577            0  ...         0        0     0      0     0
# ...                          ...  ...       ...      ...   ...    ...   ...
# 1241078443179155457            0  ...         0        0     0      0     0
# 1241085785060847617            0  ...         0        0     0      0     0
# 1241086391267872770            0  ...         0        0     0      0     0
# 1241086505566732289            0  ...         0        0     0      0     0
# 1241086382875033600            0  ...         0        0     0      0     0
#
#                      saw  provide  behead  hospital  source class
# id
# 1250219116993974272    0        0       0         0     nonrumour
# 1250219437027766273    0        0       0         0     nonrumour
# 1250219620939657216    0        0       0         0     nonrumour
# 1250219777185873922    0        0       0         0     nonrumour
# 1250219894429208577    0        0       0         0     nonrumour
# ...                  ...      ...     ...       ...           ...
# 1241078443179155457    0        0       0         0     nonrumour
# 1241085785060847617    0        0       0         0     nonrumour
# 1241086391267872770    0        0       0         0     nonrumour
# 1241086505566732289    0        0       0         0     nonrumour
# 1241086382875033600    0        0       0         0     nonrumour
#
# [28485 rows x 509 columns]

# %%
def onehot_encode_tokens(df, top_users):
    for i, row in df.iterrows():
        for token in row['tokens']:
            if token in top_users:
                df.at[i, token] = 1
    df.drop(['tokens'],axis=1,inplace=True)
    return df
train_sources = onehot_encode_tokens(train_sources, source_top_tokens)
dev_sources = onehot_encode_tokens(dev_sources, source_top_tokens)
test_sources = onehot_encode_tokens(test_sources, source_top_tokens)

train_replies = onehot_encode_tokens(train_replies, reply_top_tokens)
dev_replies = onehot_encode_tokens(dev_replies, reply_top_tokens)
test_replies = onehot_encode_tokens(test_replies, reply_top_tokens)
train_replies
# Out:
#                              user  verified  followers  retweets  favorites  \
# id
# 1250219116993974272     ucoptempe         0          1         0          0
# 1250219437027766273     ucoptempe         0          1         0          0
# 1250219620939657216     ucoptempe         0          1         0          0
# 1250219777185873922     ucoptempe         0          1         0          0
# 1250219894429208577     ucoptempe         0          1         0          0
# ...                           ...       ...        ...       ...        ...
# 1241078443179155457  lynneSimpkin         0          1         0          1
# 1241085785060847617  lynneSimpkin         0          1         0          1
# 1241086391267872770    rosierawle         0          2         0          1
# 1241086505566732289  lynneSimpkin         0          1         0          1
# 1241086382875033600  lynneSimpkin         0          1         0          0
#
#                      statuses_count  polarity  covid  coronavirus  people  \
# id
# 1250219116993974272           26613  0.136364      1            1       0
# 1250219437027766273           26613  0.136364      0            1       0
# 1250219620939657216           26613  0.136364      0            1       0
# 1250219777185873922           26613  0.368182      0            1       1
# 1250219894429208577           26613  0.136364      0            1       0
# ...                             ...       ...    ...          ...     ...
# 1241078443179155457            5118  0.418182      0            0       0
# 1241085785060847617            5118 -0.066667      0            0       0
# 1241086391267872770            5507  0.225000      0            0       0
# 1241086505566732289            5118  0.000000      0            0       0
# 1241086382875033600            5118 -0.166667      0            0       0
#
#                      ...  chlorine  weather  turn  study  kind  saw  provide  \
# id                   ...
# 1250219116993974272  ...         0        0     0      0     0    0        0
# 1250219437027766273  ...         0        0     0      0     0    0        0
# 1250219620939657216  ...         1        0     0      0     0    0        0
# 1250219777185873922  ...         0        0     0      0     0    0        0
# 1250219894429208577  ...         0        0     0      0     0    0        0
# ...                  ...       ...      ...   ...    ...   ...  ...      ...
# 1241078443179155457  ...         0        0     0      0     0    0        0
# 1241085785060847617  ...         0        0     0      0     0    0        0
# 1241086391267872770  ...         0        0     0      0     0    0        0
# 1241086505566732289  ...         0        0     0      0     0    0        0
# 1241086382875033600  ...         0        0     0      0     0    0        0
#
#                      behead  hospital  source class
# id
# 1250219116993974272       0         0     nonrumour
# 1250219437027766273       0         0     nonrumour
# 1250219620939657216       0         0     nonrumour
# 1250219777185873922       0         0     nonrumour
# 1250219894429208577       0         0     nonrumour
# ...                     ...       ...           ...
# 1241078443179155457       0         0     nonrumour
# 1241085785060847617       0         0     nonrumour
# 1241086391267872770       0         0     nonrumour
# 1241086505566732289       0         0     nonrumour
# 1241086382875033600       0         0     nonrumour
#
# [28485 rows x 508 columns]

# %%
print(len(train_sources.columns))
print(len(dev_sources.columns))
print(len(test_sources.columns))
# Out:
# 508
# 508
# 508

# %% [markdown]
# One-hot encoding for users

# %%
"""
def add_dummies(df, dummy_columns):

    dummies = pd.get_dummies(df['user'], columns=dummy_columns)
    
    df = pd.concat([df, dummies], axis=1)
    
    return df
source_dummies = pd.get_dummies(train_sources['user'])
#train_sources = add_dummies(train_sources, source_dummies.columns)

"""
# Out:
# "\ndef add_dummies(df, dummy_columns):\n\n    dummies = pd.get_dummies(df['user'], columns=dummy_columns)\n    \n    df = pd.concat([df, dummies], axis=1)\n    \n    return df\nsource_dummies = pd.get_dummies(train_sources['user'])\n#train_sources = add_dummies(train_sources, source_dummies.columns)\n\n"

# %%
"""
dev_sources = add_dummies(dev_sources, source_dummies)
test_sources = add_dummies(test_sources, source_dummies)

reply_dummies = pd.get_dummies(train_replies['user'])

train_replies = add_dummies(train_replies, reply_dummies.columns)
dev_replies = add_dummies(dev_replies, reply_dummies.columns)
test_replies = add_dummies(test_replies, reply_dummies.columns)
train_replies

"""
# Out:
# "\ndev_sources = add_dummies(dev_sources, source_dummies)\ntest_sources = add_dummies(test_sources, source_dummies)\n\nreply_dummies = pd.get_dummies(train_replies['user'])\n\ntrain_replies = add_dummies(train_replies, reply_dummies.columns)\ndev_replies = add_dummies(dev_replies, reply_dummies.columns)\ntest_replies = add_dummies(test_replies, reply_dummies.columns)\ntrain_replies\n\n"

# %%
print(len(train_sources.columns))
print(len(dev_sources.columns))
print(len(test_sources.columns))
# Out:
# 508
# 508
# 508

# %%
train_sources.drop(['user'],axis=1,inplace=True)
dev_sources.drop(['user'],axis=1,inplace=True)
test_sources.drop(['user'],axis=1,inplace=True)
train_replies.drop(['user'],axis=1,inplace=True)
dev_replies.drop(['user'],axis=1,inplace=True)
test_replies.drop(['user'],axis=1,inplace=True)

# %%
def count_rumours(df):
    rumour_count = {'nonrumour': 0, 'rumour':0}
    for id, x in df['source class'].iteritems():
        rumour_count[x]+=1
    return rumour_count
print("Train replies rumors: ")   
print(count_rumours(train_replies))
print("Dev replies rumors: ")   
print(count_rumours(dev_replies))
# Out:
# Train replies rumors:
# {'nonrumour': 15785, 'rumour': 12700}
# Dev replies rumors:
# {'nonrumour': 6195, 'rumour': 3727}

# %%
test_sources
# Out:
#                      verified  followers  retweets  favorites  statuses_count  \
# id
# 1249529725019738113         0          1         0          0            1297
# 663722803489808384          1          6        80         74          466664
# 1245172237977767936         0          1         0          0             708
# 1244004581010550785         0          2         0          0           69134
# 1245764856835342338         1          5        14         32           18066
# ...                       ...        ...       ...        ...             ...
# 553061846081896449          1          6      3042       2369           57041
# 523863683928457216          1          6      1169        626          334838
# 1278345269751492611         0          2        10         54           16214
# 1249209381813714944         0          1         0          0            2175
# 509478961705807872          1          6       105         47           80767
#
#                      polarity  covid  coronavirus  new  virus  ...  extremely  \
# id                                                             ...
# 1249529725019738113  0.000000      1            0    0      0  ...          0
# 663722803489808384   0.000000      0            0    0      0  ...          0
# 1245172237977767936  0.000000      1            0    0      0  ...          0
# 1244004581010550785  0.333333      1            0    0      0  ...          0
# 1245764856835342338  0.000000      0            1    0      0  ...          0
# ...                       ...    ...          ...  ...    ...  ...        ...
# 553061846081896449   0.000000      0            0    0      0  ...          0
# 523863683928457216   0.000000      0            0    0      0  ...          0
# 1278345269751492611  0.000000      0            0    0      0  ...          0
# 1249209381813714944  0.230000      1            0    0      0  ...          0
# 509478961705807872   0.100000      0            0    0      0  ...          0
#
#                      frediboat  likely  coronavirusupdates  bad  \
# id
# 1249529725019738113          0       0                   0    0
# 663722803489808384           0       0                   0    0
# 1245172237977767936          0       0                   0    0
# 1244004581010550785          0       0                   0    0
# 1245764856835342338          0       0                   0    0
# ...                        ...     ...                 ...  ...
# 553061846081896449           0       0                   0    0
# 523863683928457216           0       0                   0    0
# 1278345269751492611          0       0                   0    0
# 1249209381813714944          0       0                   0    0
# 509478961705807872           0       0                   0    0
#
#                      coronafreepakistan  th  sir  wrong  class
# id
# 1249529725019738113                   0   0    0      0      0
# 663722803489808384                    0   0    0      0      0
# 1245172237977767936                   0   0    0      0      0
# 1244004581010550785                   0   0    0      0      0
# 1245764856835342338                   0   0    0      0      0
# ...                                 ...  ..  ...    ...    ...
# 553061846081896449                    0   0    0      0      0
# 523863683928457216                    0   0    0      0      0
# 1278345269751492611                   0   0    0      0      0
# 1249209381813714944                   0   0    0      0      0
# 509478961705807872                    0   0    0      0      0
#
# [558 rows x 507 columns]

# %% [markdown]
# **Scaling**

# %%
scaler = StandardScaler()
for feature in ['retweets', 'favorites', 'statuses_count']:
    train_sources[feature] = scaler.fit_transform(train_sources[feature].values.reshape(-1,1))
    dev_sources[feature] = scaler.transform(dev_sources[feature].values.reshape(-1,1))
    test_sources[feature] = scaler.transform(test_sources[feature].values.reshape(-1,1))

    train_replies[feature] = scaler.fit_transform(train_replies[feature].values.reshape(-1,1))
    dev_replies[feature] = scaler.transform(dev_replies[feature].values.reshape(-1,1))
    test_replies[feature] = scaler.transform(test_replies[feature].values.reshape(-1,1))
train_sources
# Out:
#                      verified  followers  retweets  favorites  statuses_count  \
# id
# 1218255692831903744         1          6  0.207176   0.394158       -0.241400
# 1218269428166602753         1          6  5.190195   4.844430       -0.241400
# 1219979825848442880         1          6 -0.295267  -0.157160       -0.241400
# 1219981282928668672         1          6 -0.292506  -0.142259       -0.241400
# 1219982106757148673         1          6 -0.298027  -0.154676       -0.241400
# ...                       ...        ...       ...        ...             ...
# 676367888543031296          1          6  0.557782   0.158234        0.101724
# 676718762830221312          1          6  0.118835   0.376774        1.306176
# 676870737932742656          1          6  0.082946  -0.018089        1.351055
# 677099574855639044          1          6 -0.063370  -0.065273        1.351055
# 681767380305985536          1          6 -0.085455  -0.030506        1.766818
#
#                      polarity  covid  coronavirus  new  virus  ...  extremely  \
# id                                                             ...
# 1218255692831903744      0.25      0            1    0      0  ...          0
# 1218269428166602753      0.00      0            1    0      0  ...          0
# 1219979825848442880      0.00      0            1    0      0  ...          0
# 1219981282928668672      0.00      0            1    0      0  ...          0
# 1219982106757148673      0.00      0            1    0      0  ...          0
# ...                       ...    ...          ...  ...    ...  ...        ...
# 676367888543031296       0.00      0            0    0      0  ...          0
# 676718762830221312       0.00      0            0    0      0  ...          0
# 676870737932742656       0.00      0            0    0      0  ...          0
# 677099574855639044       0.00      0            0    0      0  ...          0
# 681767380305985536      -0.50      0            0    0      0  ...          0
#
#                      frediboat  likely  coronavirusupdates  bad  \
# id
# 1218255692831903744          0       0                   0    0
# 1218269428166602753          0       0                   0    0
# 1219979825848442880          0       0                   0    0
# 1219981282928668672          0       0                   0    0
# 1219982106757148673          0       0                   0    0
# ...                        ...     ...                 ...  ...
# 676367888543031296           0       0                   0    0
# 676718762830221312           0       0                   0    0
# 676870737932742656           0       0                   0    0
# 677099574855639044           0       0                   0    0
# 681767380305985536           0       0                   0    0
#
#                      coronafreepakistan  th  sir  wrong      class
# id
# 1218255692831903744                   0   0    0      0  nonrumour
# 1218269428166602753                   0   0    0      0  nonrumour
# 1219979825848442880                   0   0    0      0  nonrumour
# 1219981282928668672                   0   0    0      0  nonrumour
# 1219982106757148673                   0   0    0      0  nonrumour
# ...                                 ...  ..  ...    ...        ...
# 676367888543031296                    0   0    0      0  nonrumour
# 676718762830221312                    0   0    0      0     rumour
# 676870737932742656                    0   0    0      0     rumour
# 677099574855639044                    0   0    0      0     rumour
# 681767380305985536                    0   0    0      0     rumour
#
# [1561 rows x 507 columns]

# %%
indicies = joblib.load('Data/indexs.data')
indicies
# Out:
# ['1246482832316301319',
#  '1252279738099433473',
#  '1236050255394877440',
#  '1235582115900796928',
#  '1258787515592572928',
#  '518827403452637184',
#  '489829414704648192',
#  '580348081100734464',
#  '1248121143808098305',
#  '1258487399014858752',
#  '555072815154475008',
#  '629503919098429440',
#  '1229732608889802753',
#  '489836441120145408',
#  '1240570885662289920',
#  '1234884616479051777',
#  '1244004581010550785',
#  '1248902780556693506',
#  '1249529725019738113',
#  '1248769432748466177',
#  '1250659810044829696',
#  '1271506581352562688',
#  '525049639016615937',
#  '376874273601630208',
#  '1268842488980221953',
#  '524923462398513152',
#  '1251522113141215232',
#  '524975705206304769',
#  '1242485261734301702',
#  '633949800761700352',
#  '1267237406056558592',
#  '550038665653542913',
#  '535252460148113409',
#  '1274828323508621312',
#  '1230539788488495108',
#  '1240721296511598592',
#  '1241107812551458816',
#  '1269660260299669504',
#  '1240341381773549568',
#  '1259739644981215235',
#  '1278262917360693248',
#  '663722803489808384',
#  '524991067675189250',
#  '407163869673443328',
#  '552792913910833152',
#  '1241390215656333312',
#  '1250356617813557250',
#  '1244339469244862466',
#  '1243757859676000257',
#  '1232541995815571456',
#  '1229770637880840194',
#  '1248670865182556170',
#  '491591245152935936',
#  '524962676665888769',
#  '544391533240516608',
#  '501785003144273921',
#  '489836271049928704',
#  '1240302223881625600',
#  '1252868603411525632',
#  '1249596439174557696',
#  '1239251546275221506',
#  '1248762939261116421',
#  '1249728188286197763',
#  '524928119955013632',
#  '1243565007805255681',
#  '1250220272306638848',
#  '673079581520318464',
#  '523126268603031552',
#  '1238775642042372096',
#  '1237274979315724288',
#  '1237868142463840262',
#  '1223585697778556928',
#  '1256358837835030529',
#  '676094756758364160',
#  '1248524574217490432',
#  '560207034545889281',
#  '1256305612041814016',
#  '673615263040798726',
#  '661299012386095105',
#  '1245172237977767936',
#  '1248608866167742467',
#  '1246921819073982464',
#  '663904307113275392',
#  '1244717429609189381',
#  '532208816692416512',
#  '1244610406355779584',
#  '1251746313487757314',
#  '1241235969791209473',
#  '519348106836860929',
#  '1239188532259966978',
#  '1248778880262995968',
#  '1237030008067166208',
#  '1247072275331002369',
#  '1247218202796535809',
#  '1243904377456226304',
#  '1251435176980332555',
#  '1245764856835342338',
#  '1243616343976534016',
#  '620367840902782976',
#  '1225194419843813376',
#  '1263649035912650752',
#  '535579674152148992',
#  '552832817089236992',
#  '365276206381268995',
#  '1244323325729439746',
#  '1273236678505889800',
#  '534678919656775680',
#  '524685073979678721',
#  '524923676484177920',
#  '647169573599449088',
#  '518866406512025602',
#  '614608936491188225',
#  '1252978963426803712',
#  '1219977126742544384',
#  '509464271118688257',
#  '1243559430958039041',
#  '1277286871651975168',
#  '1222182262130823168',
#  '538218607822770176',
#  '1249341627824390155',
#  '544698560655400961',
#  '1255451744492019712',
#  '1250492351069511681',
#  '536835346932441088',
#  '1240894108316643329',
#  '509152237503778816',
#  '387281927427727360',
#  '615494435074363392',
#  '1274140194086817793',
#  '651825062174195712',
#  '1252408181260603395',
#  '544382892378714113',
#  '568075025418317826',
#  '1250220987238383616',
#  '1246756358608871424',
#  '521789009576476673',
#  '1244912804844523521',
#  '516729950091493376',
#  '407163499723624449',
#  '1225687494886191104',
#  '552498516225179650',
#  '515598200796090369',
#  '357299879070023680',
#  '1240497782097620992',
#  '656595123590012928',
#  '1264249669044977669',
#  '525033697045925888',
#  '523535962962280448',
#  '1242365913430667266',
#  '1234157123531083777',
#  '1278071380161048576',
#  '532276693931945984',
#  '544268732046913536',
#  '1248769427648253954',
#  '535474881090322432',
#  '618805892222468096',
#  '504304227246538752',
#  '1237162888869093376',
#  '535315394127728641',
#  '1248525457286258689',
#  '614638036593299456',
#  '1234566237314666496',
#  '614614133410033664',
#  '1255630453949837318',
#  '1249019022164799488',
#  '1274896295472377856',
#  '531183173443801088',
#  '1250219116993974272',
#  '1242485439665041408',
#  '1224642863419416578',
#  '1235239045187268613',
#  '513922322915282945',
#  '1222929006967869442',
#  '647464349611589632',
#  '1248087887473602560',
#  '524976980799000578',
#  '553590459688570880',
#  '1241047449348632577',
#  '1248769413043683328',
#  '1233555360826265600',
#  '1242015452332806144',
#  '1235122005004804098',
#  '1236627986717323264',
#  '650128194209730561',
#  '1240948885910179841',
#  '1241330909367939072',
#  '538256153080127489',
#  '1250202120076161025',
#  '532007252677656576',
#  '614626710248534016',
#  '515918632178577408',
#  '1253645219188355073',
#  '1252284632483020814',
#  '1221500792005447680',
#  '1242756999240208385',
#  '1252469613176082440',
#  '1250258210243698688',
#  '1244705540065955847',
#  '1244895539394572288',
#  '1242069705633882112',
#  '1276223825793839104',
#  '1238926528454385664',
#  '1270693154698788866',
#  '1234019691498295297',
#  '80080680482123777',
#  '1239325309134086145',
#  '644229386149888001',
#  '1243448361484763137',
#  '524923341359300608',
#  '1248525002028146688',
#  '514098833253748736',
#  '542600886653292545',
#  '489872119158046720',
#  '668849913678209024',
#  '519929168864497664',
#  '495365942726381568',
#  '1247863014080028673',
#  '1274043364149653505',
#  '531568534066057217',
#  '377519445578895360',
#  '1237323520142696449',
#  '514535408126795776',
#  '1241596183874863105',
#  '1270708758642135041',
#  '525088864416043008',
#  '1258349086597615616',
#  '1247232361500114948',
#  '1260958031518609408',
#  '1239019183398060033',
#  '1255537146938691584',
#  '1244476323881336832',
#  '1253477251498164224',
#  '1248616431802920961',
#  '1245824031510667265',
#  '1240724896457601026',
#  '1263985744940589058',
#  '1270632467213549568',
#  '662430295254175744',
#  '1221834674386997249',
#  '547803254516490240',
#  '1251054685538181121',
#  '1237902125704888322',
#  '407191058108256257',
#  '1268224832380043264',
#  '1221831204418334721',
#  '1242958702556016640',
#  '1242587275776516096',
#  '1243818762211557378',
#  '524941504796962816',
#  '1243191807384535040',
#  '1254125580351569921',
#  '1257607679767347201',
#  '1273583902469361664',
#  '1260009210831491073',
#  '1233023914495954946',
#  '1234884644870352896',
#  '407237676350185475',
#  '636925368927064064',
#  '1252315501214273537',
#  '1239895097040416769',
#  '407206094747209728',
#  '656818921979310081',
#  '407193347279699968',
#  '1225687455317151744',
#  '1222922750546923521',
#  '614599815280857088',
#  '527138218505175040',
#  '1250142275084136448',
#  '366025766183514112',
#  '1242034279841841154',
#  '1237312079440285696',
#  '637873886072320001',
#  '524944881941495809',
#  '372901260183494656',
#  '1232924186219339777',
#  '524979548195024898',
#  '1233005480672473091',
#  '539254751343681536',
#  '1240324491986731008',
#  '1242958703436824576',
#  '1257445088298512386',
#  '1251056988303364099',
#  '1232924379274719234',
#  '514067907475959808',
#  '523655026485366784',
#  '1239557784666071040',
#  '1246368667169783808',
#  '1259642066663079939',
#  '1241805420181757957',
#  '1252188225684344832',
#  '1236670028147314690',
#  '1235127762467377152',
#  '501881262240694272',
#  '1223278788089470977',
#  '669201837187334144',
#  '1255175204348858370',
#  '544358564484378624',
#  '1256259379856277504',
#  '1276173226171863042',
#  '1235105420252856321',
#  '641443248909754368',
#  '1241406592920064000',
#  '507557659206516736',
#  '544457299667202048',
#  '1246848873513005057',
#  '544476808566276097',
#  '1225095857583927299',
#  '544504183341064192',
#  '525024181218725888',
#  '551120768164462592',
#  '1227148217394978817',
#  '1246917232631955464',
#  '1252281210384064512',
#  '1239656563029217281',
#  '1255268594709073921',
#  '1254624942433251328',
#  '1239915291196473345',
#  '544512664769396736',
#  '513749585391390720',
#  '1256246327903752193',
#  '514508854990999553',
#  '1233113048120020994',
#  '542860306603868160',
#  '1247237838485237763',
#  '1251668952993927170',
#  '1241329705522999297',
#  '1223993219022753793',
#  '1277760718415245319',
#  '1252145401806966787',
#  '1248666174042374144',
#  '1235970785002561537',
#  '656825206045020160',
#  '1263122359994781696',
#  '407173794583695360',
#  '1239536001665638400',
#  '615840865815298048',
#  '1251054690588135425',
#  '387220814531395584',
#  '551103664124100608',
#  '531607884220485632',
#  '543319210659971073',
#  '623599854661541888',
#  '427924694663454720',
#  '1248525224938618882',
#  '1244143623635116033',
#  '665575674485211136',
#  '537355288295518210',
#  '1251176149591511040',
#  '1242070704310243330',
#  '1224095170477481984',
#  '489833932813516800',
#  '1254035404799516674',
#  '613294443878305796',
#  '1235239041441943554',
#  '1276549651265654786',
#  '524950507023245313',
#  '1242153442208026632',
#  '1257232683362660352',
#  '1242669446478671872',
#  '1240989772866338816',
#  '1251054694014824448',
#  '1236050331940855808',
#  '498430783699554305',
#  '1239310280557019139',
#  '1268702744870678528',
#  '1255992805672902656',
#  '1251310985094316033',
#  '1238028753659256832',
#  '568905632998412288',
#  '1249234760297148418',
#  '1238424497700691970',
#  '1250379310201999360',
#  '531833233143783424',
#  '626739062792032256',
#  '1237015288589307905',
#  '673581371458199552',
#  '1219980594521739265',
#  '1252260737021546496',
#  '572002458647412736',
#  '1254482034824638464',
#  '1249866103586578432',
#  '1232924440553496576',
#  '553098571323437056',
#  '1265668003301130242',
#  '547101266313089024',
#  '1240398845491765248',
#  '1235123649159598084',
#  '1218250153901076482',
#  '407170170533064705',
#  '504433135036407808',
#  '1270704437577818113',
#  '1242460228517535744',
#  '524947149134774272',
#  '489902412900343809',
#  '530943279161155584',
#  '1257079462748844033',
#  '1250004085685678080',
#  '1252678658860306432',
#  '1237712886459490304',
#  '551106793959862272',
#  '518830518792892416',
#  '387031585834278912',
#  '1245797723611201538',
#  '455525437351800832',
#  '1240171759724154881',
#  '1275994059534766086',
#  '370855596050108416',
#  '681147789653356544',
#  '1242161191960678401',
#  '407231591191035904',
#  '1272307234001821697',
#  '1240237378041778176',
#  '553186555150749696',
#  '1248490841053605888',
#  '651959206287908868',
#  '656811196218286080',
#  '1250696428403388419',
#  '1264846216761872388',
#  '1249664310877376513',
#  '1277610026404917248',
#  '1238510064027209730',
#  '482880640560271361',
#  '491241885399539712',
#  '544515538383564801',
#  '1248605782813392896',
#  '1256101133736697860',
#  '1239843424691339264',
#  '560474897013415936',
#  '1223590209486573568',
#  '1252938233249443840',
#  '656830586577883136',
#  '628681462976528384',
#  '641088973717110784',
#  '1252195584737452033',
#  '1243417698974883843',
#  '1243353600186818560',
#  '1256276448995770368',
#  '507257950868885504',
#  '519112613800972288',
#  '527295015643394048',
#  '1250100846144057348',
#  '675065047710892033',
#  '1243651257912430593',
#  '1275291205639778304',
#  '1238460460866863105',
#  '1249188918500753416',
#  '500378223977721856',
#  '1234884632627122176',
#  '1236627989036781569',
#  '1253135163820634112',
#  '1242578357495218176',
#  '1241328689436135425',
#  '1238325240536551424',
#  '1233565837073608704',
#  '1239510439920316416',
#  '674301960787505153',
#  '1242350943443865600',
#  '552792544132997121',
#  '1251054683692597248',
#  '1237267351088910336',
#  '1256093654147428353',
#  '1260920875165024262',
#  '524593547807178753',
#  '1235238338711478273',
#  '1243443187630342144',
#  '1237162887812124673',
#  '1253959004436467713',
#  '1252306840374951938',
#  '1242088874924441602',
#  '1238293201108094976',
#  '1264311672057069568',
#  '524923293711998976',
#  '1223521014195376128',
#  '1264926045276422144',
#  '618804516578680832',
#  '1243384220845608961',
#  '534303066867367937',
#  '635632641635667968',
#  '553531413459660800',
#  '1239326621514915840',
#  '1237770514954956801',
#  '518924377791164420',
#  '524952094986350592',
#  '1277199351639654404',
#  '1241325788395233280',
#  '1246830448254181385',
#  '489812926828924928',
#  '1224201250876489729',
#  '1243285526850859008',
#  '1253630441338179585',
#  '1234328552729792512',
#  '1229508745677414405',
#  '531659884430106624',
#  '1238211457000427520',
#  '1276834267864150017',
#  '1244916464789970945',
#  '1242875894340956161',
#  '1271670872261029889',
#  '544491151118860289',
#  '614593386188828672',
#  '1223521041793847297',
#  '1245512289278668800',
#  '1267178201140342785',
#  '1278345269751492611',
#  '1244915128987979777',
#  '427666815842414592',
#  '518665533089406976',
#  '1226812599569932288',
#  '1235834475348496385',
#  '1238410449823072256',
#  '1244705530595151873',
#  '510916725953417218',
#  '1242211013925142530',
#  '523863683928457216',
#  '509464457836511232',
#  '614790312955904000',
#  '1245736128734527488',
#  '1277836121523838976',
#  '491200302365040640',
#  '1254198904331079680',
#  '1238206094050308097',
#  '1277033220433993732',
#  '1245272393712615425',
#  '668144671772778497',
#  '1237060019562168320',
#  '532276370953752576',
#  '1245989574905602050',
#  '1278470852540055552',
#  '1225687482139758594',
#  '1265298431670734848',
#  '536849906997415936',
#  '1243173672841601027',
#  '1251924696519471105',
#  '553061846081896449',
#  '489796998615547904',
#  '1244000422882430977',
#  '1240167195193139200',
#  '1243364881757134848',
#  '1249614502494187520',
#  '1226929062171545600',
#  '1239139106451386374',
#  '1240697654222286849',
#  '1242485345037348865',
#  '1249209381813714944',
#  '525039784503541760',
#  '1250808942189404161',
#  '531129816389779456',
#  '509478961705807872',
#  '1260564881364979717',
#  '521717368264093696',
#  '407290871856369664',
#  '551099691702956032',
#  '528976109518721024',
#  '427944719612915712',
#  '531206167302012929',
#  '553099685888790528',
#  '1222928724112396288',
#  '1239324381215707139']

# %%
test_sources.index = test_sources.index.map(str)
test_sources2 = test_sources.reindex(indicies)
test_sources2
# Out:
#                      verified  followers  retweets  favorites  statuses_count  \
# id
# 1246482832316301319         1          6 -0.350480  -0.254013        0.236958
# 1252279738099433473         0          1 -0.350480  -0.263946       -0.330739
# 1236050255394877440         0          3 -0.350480  -0.258980       -0.583543
# 1235582115900796928         0          1 -0.339437  -0.256496       -0.590637
# 1258787515592572928         0          1 -0.350480  -0.263946       -0.246094
# ...                       ...        ...       ...        ...             ...
# 427944719612915712          1          6  0.013929  -0.201861        1.563664
# 531206167302012929          1          6  0.113313   0.510878       -0.100541
# 553099685888790528          1          6  0.582628   0.284888        0.249009
# 1222928724112396288         1          6 -0.298027  -0.144743       -0.241400
# 1239324381215707139         0          2 -0.347720  -0.261463       -0.492576
#
#                      polarity  covid  coronavirus  new  virus  ...  extremely  \
# id                                                             ...
# 1246482832316301319  0.000000      1            0    0      0  ...          0
# 1252279738099433473 -0.800000      0            0    0      1  ...          0
# 1236050255394877440  0.000000      1            1    0      1  ...          0
# 1235582115900796928  0.258333      1            0    0      0  ...          0
# 1258787515592572928  0.200000      0            0    0      0  ...          0
# ...                       ...    ...          ...  ...    ...  ...        ...
# 427944719612915712   0.000000      0            0    0      0  ...          0
# 531206167302012929  -0.200000      0            0    0      0  ...          0
# 553099685888790528   0.000000      0            0    0      0  ...          0
# 1222928724112396288  0.000000      0            1    0      0  ...          0
# 1239324381215707139  0.255556      1            0    0      0  ...          0
#
#                      frediboat  likely  coronavirusupdates  bad  \
# id
# 1246482832316301319          0       0                   0    0
# 1252279738099433473          0       0                   0    0
# 1236050255394877440          0       0                   0    0
# 1235582115900796928          0       0                   0    0
# 1258787515592572928          0       0                   0    0
# ...                        ...     ...                 ...  ...
# 427944719612915712           0       0                   0    0
# 531206167302012929           0       0                   0    0
# 553099685888790528           0       0                   0    0
# 1222928724112396288          0       0                   0    0
# 1239324381215707139          0       0                   0    0
#
#                      coronafreepakistan  th  sir  wrong  class
# id
# 1246482832316301319                   0   0    0      0      0
# 1252279738099433473                   0   0    0      0      0
# 1236050255394877440                   0   0    0      0      0
# 1235582115900796928                   0   0    0      0      0
# 1258787515592572928                   0   0    0      0      0
# ...                                 ...  ..  ...    ...    ...
# 427944719612915712                    0   0    0      0      0
# 531206167302012929                    0   0    0      0      0
# 553099685888790528                    0   0    0      0      0
# 1222928724112396288                   0   0    0      0      0
# 1239324381215707139                   0   0    0      0      0
#
# [558 rows x 507 columns]

# %%
working_path = "Processed Data/"
joblib.dump(train_sources, working_path + "pp_train_sources.data")
joblib.dump(dev_sources, working_path + "pp_dev_sources.data")
joblib.dump(test_sources2, working_path + "pp_test_sources.data")

joblib.dump(train_replies, working_path + "pp_train_replies.data")
joblib.dump(dev_replies, working_path + "pp_dev_replies.data")
joblib.dump(test_replies, working_path + "pp_test_replies.data")
# Out:
# ['Processed Data/pp_test_replies.data']
