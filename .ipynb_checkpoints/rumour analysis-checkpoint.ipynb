# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords, wordnet
import tweepy

covid_df = pd.read_csv("covid_df.csv")
covid_df.fillna(value="",inplace=True)
covid_df.drop(list(covid_df.columns)[0],axis=1,inplace=True)
rumours = covid_df[covid_df['label']==1]
nonrumours = covid_df[covid_df['label']==0]

covid_df
# Out:
#                                                     text            user  \
# 0      According to the New York Times, Warner Bros. ...  TheFilmUpdates
# 1      Hurricane Hanna has made landfall in Texas.\n\...    TexasTribune
# 2      Monkeys on the loose in India with stolen coro...         thehill
# 3      “If Trump felt comfortable having it here, the...        HeidiNBC
# 4      DISTURBING: Alabama officials say some student...            ABC7
# ...                                                  ...             ...
# 15957  I wonder how many lives could’ve been saved if...          funder
# 15958  The @thetimes front page on 17th March. The fi...   NadineDorries
# 15959  Trump just completed the racism trifecta in a ...      DNCWarRoom
# 15960  Here are a few of my photographs from today’s ...  Jess__Taylor__
# 15961  ‘IT’S GONE’: Bill De Blasio Says NYC Facing $9...     seanhannity
#
#        verified    likes  retweets  hashtag  sentiment  followers   statuses  \
# 0         False    260.0      25.0    Tenet   0.296591    45008.0     5654.0
# 1          True    580.0     479.0            0.000000   297392.0   110931.0
# 2          True    164.0      72.0           -0.076923  4362459.0  1013903.0
# 3          True   1952.0     786.0            0.400000   204299.0    19775.0
# 4          True    471.0     256.0  COVID19  -0.125000  1178868.0   256495.0
# ...         ...      ...       ...      ...        ...        ...        ...
# 15957      True  10632.0    2567.0            0.200000  1073597.0   305211.0
# 15958      True    772.0     227.0            0.125000   128557.0    29621.0
# 15959      True    915.0     367.0           -0.388889    88433.0    10988.0
# 15960     False    343.0     153.0  COVID19  -0.200000     8044.0      692.0
# 15961      True   2037.0     638.0           -0.125000  5836903.0    18633.0
#
#        label
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ...      ...
# 15957      1
# 15958      0
# 15959      1
# 15960      0
# 15961      1
#
# [15962 rows x 10 columns]

# %%
def preprocess_df(df):
    preprocessed = df.copy(deep=True)
    text = list(preprocessed['text'])
    verified = list(preprocessed['verified'])
    for i in range(len(text)):
        text[i] = " ".join(filter(lambda x:x[0]!='@', text[i].split()))
        text[i] = " ".join(filter(lambda x:x[0:4]!='http', text[i].split()))
        text[i] = " ".join(filter(lambda x:x[0:4]!='&amp', text[i].split()))
        text[i] = re.sub(r'[^a-zA-Z ]','',text[i])
        text[i] = " ".join(filter(lambda x:x[0:1]!='Q', text[i].split()))
        text[i] = " ".join(filter(lambda x:x[0:1]!='A', text[i].split()))
    preprocessed['text'] = text
    for j in range(len(verified)):
        if verified[j]:
            verified[j] = 1
        else:
            verified[j] = 0
    preprocessed['verified'] = verified
    preprocessed.fillna('', inplace=True)
    return preprocessed

def count_column(df, col, n=20):
    d = {}
    for x in df[col]:
        x = re.sub(r'[^a-zA-Z0-9]', '', str(x)).lower()
        if x == "":
            pass
        elif x in d:
            d[x] +=1
        else:
            d[x] = 1
    d = {k: v for k, v in sorted(d.items(),key=lambda item: item[1],reverse=True)}
    for i in range(n):
        print(str(list(d.keys())[i]) + ": " + str(list(d.values())[i]))
        
def calc_average(df, col):
    print(col + " " + str(round(sum(list(df[col]))/len(list(df[col])),2)))

# %%
def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma


def tokenize_df(df):
    tokenized_df = df
    tokenized_sentence = []
    for _id, row in tokenized_df.iterrows():
        text = row['text']
        # tokenize tweet
        tokens = tt.tokenize(text)
        # convert to lowercase
        tokens = [tok.lower() for tok in tokens]
        # remove stopwords
        tokens = [tok for tok in tokens if tok not in stopwords]
        # lemmatize
        tokens = [lemmatize(tok) for tok in tokens]
        tokenized_sentence.append(tokens)
    tokenized_df.insert(1, 'tokens', tokenized_sentence)
    return tokenized_df

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()

# %%
covid = tokenize_df(preprocess_df(covid_df))
rumours = tokenize_df(preprocess_df(rumours))
nonrumours = tokenize_df(preprocess_df(nonrumours))

print("all")
calc_average(covid, 'sentiment')
calc_average(covid, 'retweets')
calc_average(covid, 'likes')
calc_average(covid, 'verified')
print()
print("rumours")
calc_average(rumours, 'sentiment')
calc_average(rumours, 'retweets')
calc_average(rumours, 'likes')
calc_average(rumours, 'verified')
print()
print("nonrumours")
calc_average(nonrumours, 'sentiment')
calc_average(nonrumours, 'retweets')
calc_average(nonrumours, 'likes')
calc_average(nonrumours, 'verified')
# Out:
# all
# sentiment 0.06
# retweets 2619.56
# likes 9683.76
# verified 0.79
#
# rumours
# sentiment 0.03
# retweets 3750.15
# likes 14223.14
# verified 0.78
#
# nonrumours
# sentiment 0.07
# retweets 2189.3
# likes 7956.26
# verified 0.8

# %%
print(f'all hashtag')
count_column(covid,'hashtag',10)
print()
print(f'rumours hashtag')
count_column(rumours,'hashtag',10)
print()
print(f'nonrumours hashtag')
count_column(nonrumours,'hashtag',10)
print()
# Out:
# all hashtag
# covid19: 1669
# coronavirus: 751
# breaking: 98
# coronaviruspandemic: 24
# covid: 23
# cdnpoli: 20
# china: 19
# covid19ph: 17
# trump: 14
# stayalert: 14
#
# rumours hashtag
# covid19: 122
# coronavirus: 119
# china: 9
# maga: 8
# breaking: 7
# trump: 6
# oann: 6
# trumpownseverydeath: 4
# stopairingtrump: 4
# trumppressconference: 4
#
# nonrumours hashtag
# covid19: 1547
# coronavirus: 632
# breaking: 91
# covid: 22
# coronaviruspandemic: 22
# cdnpoli: 18
# covid19ph: 17
# stayalert: 14
# watch: 13
# stayhomesavelives: 12

# %%
def count_tokens(df):
    d = {}
    for token_list in df['tokens']:
        for token in token_list:
            if token in d:
                d[token] +=1
            else:
                d[token] = 1
    return {k: v for k, v in sorted(d.items(),key=lambda item: item[1],reverse=True)}
                
all_count = count_tokens(covid)
rumours_count = count_tokens(rumours)
nonrumours_count = count_tokens(nonrumours)

# %%
list(all_count.keys())[0:20]
# Out:
# ['coronavirus',
#  'covid',
#  'trump',
#  'say',
#  'test',
#  'case',
#  'new',
#  'people',
#  'u',
#  'death',
#  'pandemic',
#  'state',
#  'day',
#  'president',
#  'get',
#  'go',
#  'health',
#  'one',
#  'report',
#  'positive']

# %%
list(rumours_count.values())[0:20]
# Out:
# [2297,
#  1706,
#  801,
#  701,
#  561,
#  554,
#  485,
#  479,
#  350,
#  349,
#  347,
#  297,
#  297,
#  287,
#  274,
#  273,
#  235,
#  225,
#  224,
#  200]

# %%
list(nonrumours_count.values())[0:20]
# Out:
# [5746,
#  5185,
#  1845,
#  1739,
#  1562,
#  1521,
#  1246,
#  1125,
#  1060,
#  985,
#  954,
#  895,
#  886,
#  776,
#  741,
#  726,
#  718,
#  716,
#  712,
#  630]

# %%
def bigram_count(df):
    d = {}
    for token_list in df['tokens']:
        for i in range(len(token_list)):
            if i + 1 < len(token_list):
                bigram = token_list[i] + " " + token_list[i+1]
                if bigram in d:
                    d[bigram] +=1
                else:
                    d[bigram] = 1
    return {k: v for k, v in sorted(d.items(),key=lambda item: item[1],reverse=True)}
               
all_bicount = bigram_count(covid)
rumours_bicount = bigram_count(rumours)
nonrumours_bicount = bigram_count(nonrumours)

# %%
list(all_bicount.keys())[0:20]
# Out:
# ['test positive',
#  'coronavirus pandemic',
#  'covid case',
#  'coronavirus case',
#  'president trump',
#  'covid pandemic',
#  'white house',
#  'positive coronavirus',
#  'wear mask',
#  'coronavirus death',
#  'social distance',
#  'new york',
#  'new case',
#  'positive covid',
#  'covid test',
#  'coronavirus outbreak',
#  'public health',
#  'coronavirus test',
#  'donald trump',
#  'new covid']

# %%
list(rumours_bicount.keys())[0:20]
# Out:
# ['president trump',
#  'coronavirus death',
#  'donald trump',
#  'coronavirus pandemic',
#  'coronavirus case',
#  'trump say',
#  'white house',
#  'new york',
#  'test positive',
#  'ago death',
#  'coronavirus response',
#  'wear mask',
#  'week ago',
#  'unite state',
#  'u coronavirus',
#  'trump coronavirus',
#  'die coronavirus',
#  'fox news',
#  'say coronavirus',
#  'covid death']

# %%
list(nonrumours_bicount.values())[0:20]
# Out:
# [531,
#  439,
#  404,
#  341,
#  299,
#  243,
#  216,
#  215,
#  211,
#  211,
#  210,
#  194,
#  177,
#  167,
#  163,
#  162,
#  155,
#  150,
#  144,
#  143]

# %%
def trigram_count(df):
    d = {}
    for token_list in df['tokens']:
        for i in range(len(token_list)):
            if i + 2 < len(token_list):
                trigram = token_list[i] + " " + token_list[i+1] + " " + token_list[i+2]
                if trigram in d:
                    d[trigram] +=1
                else:
                    d[trigram] = 1
    return {k: v for k, v in sorted(d.items(),key=lambda item: item[1],reverse=True)}
               
all_tricount = trigram_count(covid)
rumours_tricount = trigram_count(rumours)
nonrumours_tricount = trigram_count(nonrumours)

# %%
list(all_tricount.items())[0:20]
# Out:
# [('test positive coronavirus', 268),
#  ('test positive covid', 197),
#  ('new covid case', 127),
#  ('new coronavirus case', 95),
#  ('coronavirus task force', 90),
#  ('world health organization', 72),
#  ('new case covid', 60),
#  ('confirm covid case', 58),
#  ('president trump say', 56),
#  ('coronavirus death toll', 55),
#  ('amid coronavirus pandemic', 54),
#  ('u coronavirus death', 54),
#  ('president donald trump', 51),
#  ('white house coronavirus', 50),
#  ('week ago death', 44),
#  ('death week ago', 43),
#  ('report new case', 40),
#  ('new york city', 39),
#  ('ago death week', 38),
#  ('report new covid', 34)]

# %%
list(rumours_tricount.items())[0:20]
# Out:
# [('test positive coronavirus', 45),
#  ('week ago death', 44),
#  ('death week ago', 43),
#  ('u coronavirus death', 41),
#  ('president trump say', 39),
#  ('ago death week', 38),
#  ('president donald trump', 30),
#  ('death day ago', 27),
#  ('day ago death', 27),
#  ('report u coronavirus', 24),
#  ('ago death day', 24),
#  ('world health organization', 19),
#  ('coronavirus task force', 19),
#  ('new york time', 19),
#  ('test positive covid', 17),
#  ('amid coronavirus pandemic', 16),
#  ('chinese communist party', 16),
#  ('trump handle coronavirus', 16),
#  ('trump coronavirus response', 16),
#  ('president trump coronavirus', 14)]

# %%
list(nonrumours_tricount.items())[0:20]
# Out:
# [('test positive coronavirus', 223),
#  ('test positive covid', 180),
#  ('new covid case', 120),
#  ('new coronavirus case', 84),
#  ('coronavirus task force', 71),
#  ('new case covid', 60),
#  ('confirm covid case', 57),
#  ('world health organization', 53),
#  ('coronavirus death toll', 43),
#  ('white house coronavirus', 39),
#  ('amid coronavirus pandemic', 38),
#  ('new york city', 35),
#  ('report new covid', 34),
#  ('report new case', 32),
#  ('wear face cover', 28),
#  ('confirm case covid', 27),
#  ('number coronavirus case', 25),
#  ('due coronavirus pandemic', 25),
#  ('number confirm covid', 25),
#  ('health care worker', 25)]

# %%
rumours[rumours['retweets'] >= sorted(list(rumours['retweets']),reverse=True)[10]]
# Out:
#                                                     text  \
# 705                                       How to medical
# 1246                                a story in two parts
# 2594    I have a breathing problem lol wear a mask karen
# 2887                                 Choose your fighter
# 4564   Just a reminder its okay to blame the presiden...
# 5164                             God I love this country
# 5410      Some sports are slower More about the strategy
# 7441   is so fucking wild that the Pentagon just conf...
# 9437                   Black Lives Matter protest in Los
# 10092                                            Liftoff
# 12101  Im proud to endorse my friend for President of...
#
#                                                   tokens            user  \
# 705                                            [medical]        sarahcpr
# 1246                                  [story, two, part]       maleeezy_
# 2594          [breathe, problem, lol, wear, mask, karen]        madz1426
# 2887                                   [choose, fighter]     tifffanycuh
# 4564   [reminder, okay, blame, president, bad, thing,...    lincolnjackd
# 5164                                [god, love, country]       CorkCoypu
# 5410                           [sport, slower, strategy]  MrAndrewCotter
# 7441   [fuck, wild, pentagon, confirm, ufo, barely, n...  santiagomayer_
# 9437                 [black, live, matter, protest, los]      louie_tran
# 10092                                          [liftoff]          SpaceX
# 12101  [im, proud, endorse, friend, president, unite,...     BarackObama
#
#        verified      likes  retweets hashtag  sentiment    followers  \
# 705           1   582916.0  171359.0           0.000000    2286422.0
# 1246          0   613165.0  145668.0           0.000000        615.0
# 2594          0   321130.0  131170.0           0.800000        252.0
# 2887          0  1054577.0  305680.0           0.000000       7076.0
# 4564          0   788666.0  165941.0          -0.066667       3530.0
# 5164          0   823180.0  147153.0           0.500000      16850.0
# 5410          1   642449.0  174013.0           0.500000     451354.0
# 7441          0   805604.0  152948.0           0.183333     144412.0
# 9437          1   450446.0  129620.0          -0.166667       2958.0
# 10092         1   809466.0  213010.0           0.000000   22473263.0
# 12101         1   526829.0  148778.0           0.800000  131898428.0
#
#        statuses  label
# 705     39044.0      1
# 1246    57419.0      1
# 2594       68.0      1
# 2887    75674.0      1
# 4564    10675.0      1
# 5164    36056.0      1
# 5410    31076.0      1
# 7441   115895.0      1
# 9437    20755.0      1
# 10092    5904.0      1
# 12101   16472.0      1

# %%
nonrumours[nonrumours['retweets'] >= sorted(list(nonrumours['retweets']),reverse=True)[10]]
# Out:
#                                                     text  \
# 3862   Protect yourself and your community from coron...
# 5378   I swear we are fighting two pandemics Covid an...
# 5418   Corona virus got a survival rate nd the whole ...
# 5439   We must now realize the promise of by trusting...
# 7069          Here is part and of Cutie all in one tweet
# 7775   Last month was the first March without a schoo...
# 9118   Scientists you should wash your hands because ...
# 10636  Priest giving social distance blessings with a...
# 11182  Please watch this Especially if youve tested p...
# 12418  Hola humanos soy el Coronavirus Voy a explicar...
# 14376  I wrote out some thoughts on how to make this ...
#
#                                                   tokens             user  \
# 3862   [protect, community, coronavirus, common, sens...      BarackObama
# 5378     [swear, fight, two, pandemic, covid, stupidity]        moreki_mo
# 5418   [corona, virus, get, survival, rate, nd, whole...  TheyLoveDjJigga
# 5439   [must, realize, promise, trust, god, unify, vi...        kanyewest
# 7069                           [part, cutie, one, tweet]       jerm_cohen
# 7775   [last, month, first, march, without, school, s...     RobertKlemko
# 9118   [scientist, wash, hand, coronavirus, people, i...          NCStinn
# 10636  [priest, give, social, distance, bless, squirt...         tripgore
# 11182  [please, watch, especially, youve, test, posit...    KILLBILLEVOL1
# 12418  [hola, humanos, soy, el, coronavirus, voy, exp...            QHaRi
# 14376  [write, thought, make, moment, real, turn, poi...      BarackObama
#
#        verified      likes  retweets        hashtag  sentiment    followers  \
# 3862          1   572626.0  120074.0                 -0.178571  131898409.0
# 5378          0  1222410.0  355629.0                 -0.600000      12338.0
# 5418          0   609099.0  139247.0                  0.200000       3515.0
# 5439          1  1082377.0  248424.0     2020VISION   0.000000   30818063.0
# 7069          0   341778.0  125059.0                  0.000000      28189.0
# 7775          1   654281.0  153922.0                  0.125000      52416.0
# 9118          0   416216.0  120331.0  ClimateCrisis   0.183333       6518.0
# 10636         0   531486.0  117603.0                  0.033333       6986.0
# 11182         0   280218.0  202110.0                  0.113636       2132.0
# 12418         0   198891.0  149337.0                  0.000000      18800.0
# 14376         1   865543.0  242311.0                  0.150000  131898429.0
#
#        statuses  label
# 3862    16472.0      0
# 5378   110835.0      0
# 5418   102985.0      0
# 5439     1910.0      0
# 7069    23666.0      0
# 7775    32293.0      0
# 9118    14418.0      0
# 10636   41980.0      0
# 11182   72174.0      0
# 12418   54448.0      0
# 14376   16472.0      0

# %%
rumours[rumours['likes'] >= sorted(list(rumours['likes']),reverse=True)[10]]
# Out:
#                                                     text  \
# 705                                       How to medical
# 1246                                a story in two parts
# 2887                                 Choose your fighter
# 4231   Coronavirus is everywhere BOOK THAT FLIGHT Tak...
# 4564   Just a reminder its okay to blame the presiden...
# 5164                             God I love this country
# 5410      Some sports are slower More about the strategy
# 7441   is so fucking wild that the Pentagon just conf...
# 10092                                            Liftoff
# 11313               We cant take four more years of this
# 14803  Coronavirus said this ones for you Princess Diana
#
#                                                   tokens            user  \
# 705                                            [medical]        sarahcpr
# 1246                                  [story, two, part]       maleeezy_
# 2887                                   [choose, fighter]     tifffanycuh
# 4231   [coronavirus, everywhere, book, flight, take, ...    JardinTaylor
# 4564   [reminder, okay, blame, president, bad, thing,...    lincolnjackd
# 5164                                [god, love, country]       CorkCoypu
# 5410                           [sport, slower, strategy]  MrAndrewCotter
# 7441   [fuck, wild, pentagon, confirm, ufo, barely, n...  santiagomayer_
# 10092                                          [liftoff]          SpaceX
# 11313                           [cant, take, four, year]        JoeBiden
# 14803           [coronavirus, say, one, princess, diana]     JordanRowes
#
#        verified      likes  retweets hashtag  sentiment   followers  statuses  \
# 705           1   582916.0  171359.0           0.000000   2286422.0   39044.0
# 1246          0   613165.0  145668.0           0.000000       615.0   57419.0
# 2887          0  1054577.0  305680.0           0.000000      7076.0   75674.0
# 4231          0   653048.0  121442.0           0.000000      4930.0  115325.0
# 4564          0   788666.0  165941.0          -0.066667      3530.0   10675.0
# 5164          0   823180.0  147153.0           0.500000     16850.0   36056.0
# 5410          1   642449.0  174013.0           0.500000    451354.0   31076.0
# 7441          0   805604.0  152948.0           0.183333    144412.0  115895.0
# 10092         1   809466.0  213010.0           0.000000  22473263.0    5904.0
# 11313         1   529495.0   72035.0           0.500000  34144398.0    8194.0
# 14803         0   538362.0  113936.0           0.000000     22890.0   36248.0
#
#        label
# 705        1
# 1246       1
# 2887       1
# 4231       1
# 4564       1
# 5164       1
# 5410       1
# 7441       1
# 10092      1
# 11313      1
# 14803      1

# %%
nonrumours[nonrumours['likes'] >= sorted(list(nonrumours['likes']),reverse=True)[10]]
# Out:
#                                                     text  \
# 3862   Protect yourself and your community from coron...
# 5378   I swear we are fighting two pandemics Covid an...
# 5418   Corona virus got a survival rate nd the whole ...
# 5439   We must now realize the promise of by trusting...
# 6334   Even if you cant give the moms in your life a ...
# 6951   Update The Cleveland Clinic has developed a CO...
# 7616   i cant even remember what we used to talk abou...
# 7775   Last month was the first March without a schoo...
# 10636  Priest giving social distance blessings with a...
# 10912  My professor just told me that if we get a whi...
# 14376  I wrote out some thoughts on how to make this ...
#
#                                                   tokens             user  \
# 3862   [protect, community, coronavirus, common, sens...      BarackObama
# 5378     [swear, fight, two, pandemic, covid, stupidity]        moreki_mo
# 5418   [corona, virus, get, survival, rate, nd, whole...  TheyLoveDjJigga
# 5439   [must, realize, promise, trust, god, unify, vi...        kanyewest
# 6334   [even, cant, give, mom, life, hug, today, hope...      BarackObama
# 6951   [update, cleveland, clinic, develop, covid, te...       AndreaR9Md
# 7616      [cant, even, remember, use, talk, coronavirus]           Y2SHAF
# 7775   [last, month, first, march, without, school, s...     RobertKlemko
# 10636  [priest, give, social, distance, bless, squirt...         tripgore
# 10912  [professor, tell, get, whiff, smoke, another, ...          Lou16em
# 14376  [write, thought, make, moment, real, turn, poi...      BarackObama
#
#        verified      likes  retweets     hashtag  sentiment    followers  \
# 3862          1   572626.0  120074.0              -0.178571  131898409.0
# 5378          0  1222410.0  355629.0              -0.600000      12338.0
# 5418          0   609099.0  139247.0               0.200000       3515.0
# 5439          1  1082377.0  248424.0  2020VISION   0.000000   30818063.0
# 6334          1   653446.0   52583.0               0.325000  131898415.0
# 6951          0   537107.0   93377.0               0.143750      21981.0
# 7616          0   549150.0  106633.0               0.000000     208416.0
# 7775          1   654281.0  153922.0               0.125000      52416.0
# 10636         0   531486.0  117603.0               0.033333       6986.0
# 10912         0   591610.0   63596.0               0.000000       1596.0
# 14376         1   865543.0  242311.0               0.150000  131898429.0
#
#        statuses  label
# 3862    16472.0      0
# 5378   110835.0      0
# 5418   102985.0      0
# 5439     1910.0      0
# 6334    16472.0      0
# 6951   109779.0      0
# 7616     5184.0      0
# 7775    32293.0      0
# 10636   41980.0      0
# 10912     847.0      0
# 14376   16472.0      0

# %%
api_key = "aJTgi4d1H1zmQNkQuHeualNhP"
api_secrets = "yPFdp2Bbib25r1iPQCqBuPq8B9UzoJbIdpv1jgzEZFEg1eJl6X"
access_token = "1409382627124019204-oPpzVGuCwyFfQTfoocFhgHi68whhog"
access_secret = "esgwpH5gnRfNB0SpiHkO52mZSI5VKKnn8SG2pafEnzj2b"
 
# Authenticate to Twitter
auth = tweepy.OAuthHandler(api_key,api_secrets)
auth.set_access_token(access_token,access_secret)
 
api = tweepy.API(auth)

TWEET_OBJECT_PATH = 'tweet-objects/'
 
try:
    api.verify_credentials()
    print('Successful Authentication')
except:
    print('Failed Authentication')
# Out:
# Successful Authentication

# %%
follow = list(covid['followers'])
av_follow = round(sum(follow)/len(follow),2)

num_status = list(covid['statuses'])
av_status = round(sum(num_status)/len(num_status),2)

print("all")
print("followers: "+str(av_follow))
print("num_status: "+str(av_status))
# Out:
# all
# followers: 4926492.15
# num_status: 146871.33

# %%
follow = list(rumours['followers'])
av_follow = round(sum(follow)/len(follow),2)

num_status = list(rumours['statuses'])
av_status = round(sum(num_status)/len(num_status),2)

print("rumours")
print("followers: "+str(av_follow))
print("num_status: "+str(av_status))
# Out:
# rumours
# followers: 4376776.13
# num_status: 163150.03

# %%
follow = list(nonrumours['followers'])
av_follow = round(sum(follow)/len(follow),2)

num_status = list(nonrumours['statuses'])
av_status = round(sum(num_status)/len(num_status),2)

print("nonrumours")
print("followers: "+str(av_follow))
print("num_status: "+str(av_status))
# Out:
# nonrumours
# followers: 5135690.43
# num_status: 140676.35

# %%
nonrumours.count()
# Out:
# text         11562
# tokens       11562
# user         11562
# verified     11562
# likes        11562
# retweets     11562
# hashtag      11562
# sentiment    11562
# followers    11562
# statuses     11562
# label        11562
# dtype: int64

# %%
len(set([x for x in list(rumours.user) if x in list(nonrumours.user)]))
# Out:
# 780

# %%
len(set(list(covid.user)))
# Out:
# 6019
